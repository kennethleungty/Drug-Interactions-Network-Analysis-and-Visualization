# %% [markdown]
# ## Data Exploration
# - Data source: https://snap.stanford.edu/biodata/datasets/10001/10001-ChCh-Miner.html
# - Also see: https://github.com/snap-stanford/miner-data/tree/master/drugbank

# %%
import pyforest

# %%
df_drug_int = pd.read_csv("ChCh-Miner_durgbank-chem-chem.tsv", sep='\t', header=None)
df_drug_int.head(25)
# Out:
#           0        1
# 0   DB00862  DB00966
# 1   DB00575  DB00806
# 2   DB01242  DB08893
# 3   DB01151  DB08883
# 4   DB01235  DB01275
# 5   DB00018  DB00333
# 6   DB00201  DB01609
# 7   DB00712  DB01418
# 8   DB01576  DB04842
# 9   DB01609  DB06212
# 10  DB01232  DB09291
# 11  DB00382  DB06153
# 12  DB01017  DB01142
# 13  DB00214  DB01174
# 14  DB00104  DB00908
# 15  DB00569  DB01109
# 16  DB01222  DB09063
# 17  DB00898  DB01589
# 18  DB00762  DB09054
# 19  DB00780  DB01158
# 20  DB00186  DB09071
# 21  DB01248  DB06688
# 22  DB00484  DB00881
# 23  DB00396  DB00682
# 24  DB00368  DB01551

# %%
# Drug bank accession code
# https://go.drugbank.com/drugs/DB00254

# %%
len(df_drug_int)
# Out:
# 48514

# %%
df_drug_poly = pd.read_csv("ChChSe-Decagon_polypharmacy.csv")
df_drug_poly.head(25)
# Out:
#       # STITCH 1      STITCH 2 Polypharmacy Side Effect  \
# 0   CID000002173  CID000003345                 C0151714
# 1   CID000002173  CID000003345                 C0035344
# 2   CID000002173  CID000003345                 C0004144
# 3   CID000002173  CID000003345                 C0002063
# 4   CID000002173  CID000003345                 C0004604
# 5   CID000002173  CID000003345                 C0034063
# 6   CID000002173  CID000003345                 C0085631
# 7   CID000002173  CID000003345                 C0013384
# 8   CID000002173  CID000003345                 C0001122
# 9   CID000002173  CID000003345                 C0034150
# 10  CID000002173  CID000003345                 C0038000
# 11  CID000002173  CID000003345                 C0003578
# 12  CID000002173  CID000003345                 C0013182
# 13  CID000002173  CID000003345                 C0016204
# 14  CID000002173  CID000003345                 C0242429
# 15  CID000002173  CID000003345                 C0020517
# ...

# %%
df_drug_mono = pd.read_csv("ChSe-Decagon_monopharmacy.csv")
df_drug_mono.head(25)
# Out:
#         # STITCH Individual Side Effect                     Side Effect Name
# 0   CID003062316               C1096328          central nervous system mass
# 1   CID003062316               C0162830            Photosensitivity reaction
# 2   CID003062316               C1611725         leukaemic infiltration brain
# 3   CID003062316               C0541767       platelet adhesiveness abnormal
# 4   CID003062316               C0242973              Ventricular dysfunction
# 5   CID003062316               C1167962        cytogenetic analysis abnormal
# 6   CID003062316               C0042023                          pollakiuria
# 7   CID003062316               C0948183                         myelocytosis
# 8   CID003062316               C0744403                   gingival infection
# 9   CID003062316               C0748390      retroperitoneal lymphadenopathy
# 10  CID003062316               C0729847                iliac artery stenosis
# ...

# %% [markdown]
# ___
# ### Obtain master mapping list of CID codes (PubChem Identifier)
# - e.g. CID003062316 -> https://pubchem.ncbi.nlm.nih.gov/compound/003062316

# %% [markdown]
# ___
# ### Obtain master mapping list of DB codes (DrugBank Accens)
# - e.g. DB00254 -> https://go.drugbank.com/drugs/DB00254
