# %% [markdown]
# # Drug Interactions Network Analysis
# **Part 1 - Data Exploraton**
#
# Data Sources:
# - https://snap.stanford.edu/biodata/datasets/10001/10001-ChCh-Miner.html
# - https://github.com/snap-stanford/miner-data/tree/master/drugbank

# %% [markdown]
# ___
# ### 1. Import dependencies

# %%
import pandas as pd
import numpy as np
import re
import zipfile
import json
from pyvis.network import Network
import networkx as nx

from collections import Counter
from  itertools import combinations

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ___
# ### 2. Data preparation

# %%
# Unzip all tar/zip files
zip_files_list = [i for i in os.listdir('data') if i.endswith('.zip')]

for file in zip_files_list:
    with zipfile.ZipFile(f'data/{file}', 'r') as zip_ref:
        zip_ref.extractall('data')

os.listdir('data')
# Out:
# ['ChCh-Miner_durgbank-chem-chem.tsv',
#  'ChCh-Miner_durgbank-chem-chem.zip',
#  'ChChSe-Decagon_polypharmacy.csv',
#  'ChChSe-Decagon_polypharmacy.zip',
#  'ChSe-Decagon_monopharmacy.csv',
#  'ChSe-Decagon_monopharmacy.zip',
#  'CID_mapping.json',
#  'DB_mapping.json']

# %% [markdown]
# #### Drug Interactions (Drugbank)

# %%
# Read DB mapping JSON
with open('data/DB_mapping.json', 'r') as fp:
    db_mapping = json.load(fp)
    
db_mapping
# Out:
# {'DB00005': 'Etanercept',
#  'DB00006': 'Bivalirudin',
#  'DB00007': 'Leuprolide',
#  'DB00008': 'Peginterferon alfa-2a',
#  'DB00009': 'Alteplase',
#  'DB00012': 'Darbepoetin alfa',
#  'DB00013': 'Urokinase',
#  'DB00014': 'Goserelin',
#  'DB00015': 'Reteplase',
#  'DB00016': 'Erythropoietin',
#  'DB00017': 'Salmon calcitonin',
#  'DB00018': 'Interferon alfa-n3',
#  'DB00019': 'Pegfilgrastim',
#  'DB00020': 'Sargramostim',
#  'DB00021': 'Secretin human',
#  'DB00022': 'Peginterferon alfa-2b',
#  'DB00023': 'Asparaginase Escherichia coli',
#  'DB00026': 'Anakinra',
#  'DB00028': 'Human immunoglobulin G',
#  'DB00029': 'Anistreplase',
#  'DB00030': 'Insulin human',
#  'DB00031': 'Tenecteplase',
#  'DB00033': 'Interferon gamma-1b',
#  'DB00035': 'Desmopressin',
#  'DB00036': 'Coagulation factor VIIa Recombinant Human',
#  'DB00039': 'Palifermin',
#  'DB00040': 'Glucagon',
#  'DB00041': 'Aldesleukin',
#  'DB00042': 'Botulinum toxin type B',
#  'DB00043': 'Omalizumab',
#  'DB00046': 'Insulin lispro',
#  'DB00047': 'Insulin glargine',
#  'DB00048': 'Collagenase clostridium histolyticum',
#  'DB00050': 'Cetrorelix',
#  'DB00051': 'Adalimumab',
#  'DB00052': 'Somatotropin',
#  'DB00054': 'Abciximab',
#  'DB00056': 'Gemtuzumab ozogamicin',
#  'DB00059': 'Pegaspargase',
#  'DB00060': 'Interferon beta-1a',
#  'DB00061': 'Pegademase',
#  'DB00063': 'Eptifibatide',
#  'DB00065': 'Infliximab',
#  'DB00068': 'Interferon beta-1b',
#  'DB00069': 'Interferon alfacon-1',
#  'DB00070': 'Hyaluronidase (ovine)',
#  'DB00072': 'Trastuzumab',
#  'DB00073': 'Rituximab',
#  'DB00074': 'Basiliximab',
#  'DB00078': 'Ibritumomab tiuxetan',
#  'DB00080': 'Daptomycin',
#  'DB00081': 'Tositumomab',
#  'DB00082': 'Pegvisomant',
#  'DB00083': 'Botulinum toxin type A',
#  'DB00085': 'Pancrelipase',
#  'DB00086': 'Streptokinase',
#  'DB00087': 'Alemtuzumab',
#  'DB00089': 'Capromab pendetide',
#  'DB00091': 'Cyclosporine',
#  'DB00098': 'Antithymocyte immunoglobulin (rabbit)',
#  'DB00099': 'Filgrastim',
#  'DB00100': 'Coagulation Factor IX (Recombinant)',
#  'DB00103': 'Agalsidase beta',
#  'DB00104': 'Octreotide',
#  'DB00105': 'Interferon alfa-2b',
#  'DB00107': 'Oxytocin',
#  'DB00108': 'Natalizumab',
#  'DB00109': 'Enfuvirtide',
#  'DB00110': 'Palivizumab',
#  'DB00112': 'Bevacizumab',
#  'DB00115': 'Vitamin B12',
#  'DB00120': 'Phenylalanine',
#  'DB00121': 'Biotin',
#  'DB00122': 'Choline',
#  'DB00126': 'Vitamin C',
#  'DB00130': 'L-Glutamine',
#  'DB00136': 'Calcitriol',
#  'DB00140': 'Riboflavin',
#  'DB00146': 'Calcifediol',
#  'DB00150': 'Tryptophan',
#  'DB00153': 'Ergocalciferol',
#  'DB00158': 'Folic acid',
#  'DB00159': 'Icosapent',
#  'DB00162': 'Vitamin A',
#  'DB00163': 'Vitamin E',
#  'DB00165': 'Pyridoxine',
#  'DB00166': 'Lipoic acid',
#  'DB00169': 'Vitamin D3',
#  'DB00170': 'Menadione',
#  'DB00173': 'Adenine',
#  'DB00175': 'Pravastatin',
#  'DB00176': 'Fluvoxamine',
#  'DB00177': 'Valsartan',
#  'DB00178': 'Ramipril',
#  'DB00180': 'Flunisolide',
#  'DB00181': 'Baclofen',
#  'DB00182': 'Amphetamine',
#  'DB00184': 'Nicotine',
#  'DB00185': 'Cevimeline',
#  'DB00186': 'Lorazepam',
#  'DB00187': 'Esmolol',
#  'DB00188': 'Bortezomib',
#  'DB00190': 'Carbidopa',
#  'DB00191': 'Phentermine',
#  'DB00193': 'Tramadol',
#  'DB00195': 'Betaxolol',
#  'DB00196': 'Fluconazole',
#  'DB00197': 'Troglitazone',
#  'DB00198': 'Oseltamivir',
#  'DB00199': 'Erythromycin',
#  'DB00200': 'Hydroxocobalamin',
#  'DB00201': 'Caffeine',
#  'DB00202': 'Succinylcholine',
#  'DB00203': 'Sildenafil',
#  'DB00204': 'Dofetilide',
#  'DB00205': 'Pyrimethamine',
#  'DB00206': 'Reserpine',
#  'DB00207': 'Azithromycin',
#  'DB00208': 'Ticlopidine',
#  'DB00209': 'Trospium',
#  'DB00210': 'Adapalene',
#  'DB00211': 'Midodrine',
#  'DB00213': 'Pantoprazole',
#  'DB00214': 'Torasemide',
#  'DB00215': 'Citalopram',
#  'DB00216': 'Eletriptan',
#  'DB00218': 'Moxifloxacin',
#  'DB00220': 'Nelfinavir',
#  'DB00222': 'Glimepiride',
#  'DB00223': 'Diflorasone',
#  'DB00224': 'Indinavir',
#  'DB00227': 'Lovastatin',
#  'DB00229': 'Cefotiam',
#  'DB00230': 'Pregabalin',
#  'DB00231': 'Temazepam',
#  'DB00232': 'Methyclothiazide',
#  'DB00233': 'Aminosalicylic acid',
#  'DB00234': 'Reboxetine',
#  'DB00235': 'Milrinone',
#  'DB00237': 'Butabarbital',
#  'DB00238': 'Nevirapine',
#  'DB00240': 'Alclometasone',
#  'DB00241': 'Butalbital',
#  'DB00242': 'Cladribine',
#  'DB00243': 'Ranolazine',
#  'DB00244': 'Mesalazine',
#  'DB00245': 'Benzatropine',
#  'DB00246': 'Ziprasidone',
#  'DB00248': 'Cabergoline',
#  'DB00250': 'Dapsone',
#  'DB00251': 'Terconazole',
#  'DB00252': 'Phenytoin',
#  'DB00254': 'Doxycycline',
#  'DB00255': 'Diethylstilbestrol',
#  'DB00257': 'Clotrimazole',
#  'DB00258': 'Calcium acetate',
#  'DB00259': 'Sulfanilamide',
#  'DB00260': 'Cycloserine',
#  'DB00261': 'Anagrelide',
#  'DB00262': 'Carmustine',
#  'DB00263': 'Sulfisoxazole',
#  'DB00264': 'Metoprolol',
#  'DB00266': 'Dicoumarol',
#  'DB00267': 'Cefmenoxime',
#  'DB00268': 'Ropinirole',
#  'DB00269': 'Chlorotrianisene',
#  'DB00270': 'Isradipine',
#  'DB00271': 'Diatrizoate',
#  'DB00273': 'Topiramate',
#  'DB00274': 'Cefmetazole',
#  'DB00275': 'Olmesartan',
#  'DB00276': 'Amsacrine',
#  'DB00277': 'Theophylline',
#  'DB00278': 'Argatroban',
#  'DB00279': 'Liothyronine',
#  'DB00280': 'Disopyramide',
#  'DB00281': 'Lidocaine',
#  'DB00282': 'Pamidronic acid',
#  'DB00283': 'Clemastine',
#  'DB00284': 'Acarbose',
#  'DB00285': 'Venlafaxine',
#  'DB00287': 'Travoprost',
#  'DB00288': 'Amcinonide',
#  'DB00289': 'Atomoxetine',
#  'DB00290': 'Bleomycin',
#  'DB00291': 'Chlorambucil',
#  'DB00293': 'Raltitrexed',
#  'DB00294': 'Etonogestrel',
#  'DB00295': 'Morphine',
#  'DB00296': 'Ropivacaine',
#  'DB00297': 'Bupivacaine',
#  'DB00300': 'Tenofovir disoproxil',
#  'DB00301': 'Flucloxacillin',
#  'DB00302': 'Tranexamic acid',
#  'DB00303': 'Ertapenem',
#  'DB00304': 'Desogestrel',
#  'DB00305': 'Mitomycin',
#  'DB00307': 'Bexarotene',
#  'DB00308': 'Ibutilide',
#  'DB00309': 'Vindesine',
#  'DB00310': 'Chlorthalidone',
#  'DB00311': 'Ethoxzolamide',
#  'DB00312': 'Pentobarbital',
#  'DB00313': 'Valproic acid',
#  'DB00314': 'Capreomycin',
#  'DB00315': 'Zolmitriptan',
#  'DB00316': 'Acetaminophen',
#  'DB00317': 'Gefitinib',
#  'DB00318': 'Codeine',
#  'DB00319': 'Piperacillin',
#  'DB00320': 'Dihydroergotamine',
#  'DB00321': 'Amitriptyline',
#  'DB00322': 'Floxuridine',
#  'DB00323': 'Tolcapone',
#  'DB00324': 'Fluorometholone',
#  'DB00325': 'Nitroprusside',
#  'DB00327': 'Hydromorphone',
#  'DB00328': 'Indomethacin',
#  'DB00330': 'Ethambutol',
#  'DB00331': 'Metformin',
#  'DB00332': 'Ipratropium',
#  'DB00333': 'Methadone',
#  'DB00334': 'Olanzapine',
#  'DB00335': 'Atenolol',
#  'DB00337': 'Pimecrolimus',
#  'DB00338': 'Omeprazole',
#  'DB00339': 'Pyrazinamide',
#  'DB00341': 'Cetirizine',
#  'DB00342': 'Terfenadine',
#  'DB00343': 'Diltiazem',
#  'DB00344': 'Protriptyline',
#  'DB00345': 'Aminohippuric acid',
#  'DB00346': 'Alfuzosin',
#  'DB00347': 'Trimethadione',
#  'DB00349': 'Clobazam',
#  'DB00350': 'Minoxidil',
#  'DB00351': 'Megestrol acetate',
#  'DB00352': 'Tioguanine',
#  'DB00353': 'Methylergometrine',
#  'DB00355': 'Aztreonam',
#  'DB00356': 'Chlorzoxazone',
#  'DB00357': 'Aminoglutethimide',
#  'DB00358': 'Mefloquine',
#  'DB00359': 'Sulfadiazine',
#  'DB00360': 'Sapropterin',
#  'DB00361': 'Vinorelbine',
#  'DB00363': 'Clozapine',
#  'DB00364': 'Sucralfate',
#  'DB00366': 'Doxylamine',
#  'DB00367': 'Levonorgestrel',
#  'DB00368': 'Norepinephrine',
#  'DB00369': 'Cidofovir',
#  'DB00370': 'Mirtazapine',
#  'DB00371': 'Meprobamate',
#  'DB00373': 'Timolol',
#  'DB00374': 'Treprostinil',
#  'DB00375': 'Colestipol',
#  'DB00376': 'Trihexyphenidyl',
#  'DB00377': 'Palonosetron',
#  'DB00378': 'Dydrogesterone',
#  'DB00379': 'Mexiletine',
#  'DB00380': 'Dexrazoxane',
#  'DB00381': 'Amlodipine',
#  'DB00382': 'Tacrine',
#  'DB00384': 'Triamterene',
#  'DB00387': 'Procyclidine',
#  'DB00388': 'Phenylephrine',
#  'DB00389': 'Carbimazole',
#  'DB00390': 'Digoxin',
#  'DB00391': 'Sulpiride',
#  'DB00392': 'Profenamine',
#  'DB00393': 'Nimodipine',
#  'DB00394': 'Beclomethasone dipropionate',
#  'DB00395': 'Carisoprodol',
#  'DB00396': 'Progesterone',
#  'DB00397': 'Phenylpropanolamine',
#  'DB00398': 'Sorafenib',
#  'DB00399': 'Zoledronic acid',
#  'DB00400': 'Griseofulvin',
#  'DB00401': 'Nisoldipine',
#  'DB00402': 'Eszopiclone',
#  'DB00404': 'Alprazolam',
#  'DB00405': 'Dexbrompheniramine',
#  'DB00406': 'Gentian Violet',
#  'DB00407': 'Ardeparin',
#  'DB00408': 'Loxapine',
#  'DB00409': 'Remoxipride',
#  'DB00410': 'Mupirocin',
#  'DB00411': 'Carbachol',
#  'DB00412': 'Rosiglitazone',
#  'DB00413': 'Pramipexole',
#  'DB00414': 'Acetohexamide',
#  'DB00415': 'Ampicillin',
#  'DB00417': 'Phenoxymethylpenicillin',
#  'DB00418': 'Secobarbital',
#  'DB00420': 'Promazine',
#  'DB00421': 'Spironolactone',
#  'DB00422': 'Methylphenidate',
#  'DB00423': 'Methocarbamol',
#  'DB00424': 'Hyoscyamine',
#  'DB00425': 'Zolpidem',
#  'DB00427': 'Triprolidine',
#  'DB00428': 'Streptozocin',
#  'DB00429': 'Carboprost tromethamine',
#  'DB00430': 'Cefpiramide',
#  'DB00433': 'Prochlorperazine',
#  'DB00434': 'Cyproheptadine',
#  'DB00435': 'Nitric Oxide',
#  'DB00436': 'Bendroflumethiazide',
#  'DB00437': 'Allopurinol',
#  'DB00438': 'Ceftazidime',
#  'DB00440': 'Trimethoprim',
#  'DB00441': 'Gemcitabine',
#  'DB00442': 'Entecavir',
#  'DB00443': 'Betamethasone',
#  'DB00444': 'Teniposide',
#  'DB00445': 'Epirubicin',
#  'DB00446': 'Chloramphenicol',
#  'DB00448': 'Lansoprazole',
#  'DB00449': 'Dipivefrin',
#  'DB00450': 'Droperidol',
#  'DB00451': 'Levothyroxine',
#  'DB00452': 'Framycetin',
#  'DB00454': 'Meperidine',
#  'DB00455': 'Loratadine',
#  'DB00456': 'Cefalotin',
#  'DB00457': 'Prazosin',
#  'DB00458': 'Imipramine',
#  'DB00459': 'Acitretin',
#  'DB00460': 'Verteporfin',
#  'DB00461': 'Nabumetone',
#  'DB00465': 'Ketorolac',
#  'DB00468': 'Quinine',
#  'DB00470': 'Dronabinol',
#  'DB00471': 'Montelukast',
#  'DB00472': 'Fluoxetine',
#  'DB00474': 'Methohexital',
#  'DB00475': 'Chlordiazepoxide',
#  'DB00476': 'Duloxetine',
#  'DB00477': 'Chlorpromazine',
#  'DB00478': 'Rimantadine',
#  'DB00479': 'Amikacin',
#  'DB00480': 'Lenalidomide',
#  'DB00481': 'Raloxifene',
#  'DB00482': 'Celecoxib',
#  'DB00484': 'Brimonidine',
#  'DB00485': 'Dicloxacillin',
#  'DB00486': 'Nabilone',
#  'DB00488': 'Altretamine',
#  'DB00489': 'Sotalol',
#  'DB00490': 'Buspirone',
#  'DB00491': 'Miglitol',
#  'DB00492': 'Fosinopril',
#  'DB00493': 'Cefotaxime',
#  'DB00494': 'Entacapone',
#  'DB00495': 'Zidovudine',
#  'DB00496': 'Darifenacin',
#  'DB00497': 'Oxycodone',
#  'DB00498': 'Phenindione',
#  'DB00499': 'Flutamide',
#  'DB00500': 'Tolmetin',
#  'DB00501': 'Cimetidine',
#  'DB00502': 'Haloperidol',
#  'DB00503': 'Ritonavir',
#  'DB00508': 'Triflupromazine',
#  'DB00512': 'Vancomycin',
#  'DB00513': 'Aminocaproic acid',
#  'DB00514': 'Dextromethorphan',
#  'DB00515': 'Cisplatin',
#  'DB00518': 'Albendazole',
#  'DB00519': 'Trandolapril',
#  'DB00520': 'Caspofungin',
#  'DB00521': 'Carteolol',
#  'DB00523': 'Alitretinoin',
#  'DB00524': 'Metolazone',
#  'DB00526': 'Oxaliplatin',
#  'DB00528': 'Lercanidipine',
#  'DB00529': 'Foscarnet',
#  'DB00530': 'Erlotinib',
#  'DB00531': 'Cyclophosphamide',
#  'DB00532': 'Mephenytoin',
#  'DB00535': 'Cefdinir',
#  'DB00536': 'Guanidine',
#  'DB00537': 'Ciprofloxacin',
#  'DB00539': 'Toremifene',
#  'DB00540': 'Nortriptyline',
#  'DB00541': 'Vincristine',
#  'DB00542': 'Benazepril',
#  'DB00543': 'Amoxapine',
#  'DB00544': 'Fluorouracil',
#  'DB00545': 'Pyridostigmine',
#  'DB00547': 'Desoximetasone',
#  'DB00549': 'Zafirlukast',
#  'DB00550': 'Propylthiouracil',
#  'DB00551': 'Acetohydroxamic acid',
#  'DB00552': 'Pentostatin',
#  'DB00553': 'Methoxsalen',
#  'DB00554': 'Piroxicam',
#  'DB00555': 'Lamotrigine',
#  'DB00556': 'Perflutren',
#  'DB00557': 'Hydroxyzine',
#  'DB00559': 'Bosentan',
#  'DB00560': 'Tigecycline',
#  'DB00561': 'Doxapram',
#  'DB00563': 'Methotrexate',
#  'DB00564': 'Carbamazepine',
#  'DB00565': 'Cisatracurium',
#  'DB00567': 'Cephalexin',
#  'DB00569': 'Fondaparinux',
#  'DB00570': 'Vinblastine',
#  'DB00571': 'Propranolol',
#  'DB00572': 'Atropine',
#  'DB00573': 'Fenoprofen',
#  'DB00575': 'Clonidine',
#  'DB00577': 'Valaciclovir',
#  'DB00578': 'Carbenicillin',
#  'DB00581': 'Lactulose',
#  'DB00582': 'Voriconazole',
#  'DB00583': 'Levocarnitine',
#  'DB00584': 'Enalapril',
#  'DB00585': 'Nizatidine',
#  'DB00586': 'Diclofenac',
#  'DB00588': 'Fluticasone propionate',
#  'DB00590': 'Doxazosin',
#  'DB00591': 'Fluocinolone acetonide',
#  'DB00593': 'Ethosuximide',
#  'DB00594': 'Amiloride',
#  'DB00595': 'Oxytetracycline',
#  'DB00596': 'Ulobetasol',
#  'DB00598': 'Labetalol',
#  'DB00599': 'Thiopental',
#  'DB00601': 'Linezolid',
#  'DB00602': 'Ivermectin',
#  'DB00603': 'Medroxyprogesterone acetate',
#  'DB00604': 'Cisapride',
#  'DB00605': 'Sulindac',
#  'DB00606': 'Cyclothiazide',
#  'DB00607': 'Nafcillin',
#  'DB00608': 'Chloroquine',
#  'DB00609': 'Ethionamide',
#  'DB00610': 'Metaraminol',
#  'DB00611': 'Butorphanol',
#  'DB00612': 'Bisoprolol',
#  'DB00613': 'Amodiaquine',
#  'DB00615': 'Rifabutin',
#  'DB00618': 'Demeclocycline',
#  'DB00619': 'Imatinib',
#  'DB00620': 'Triamcinolone',
#  'DB00621': 'Oxandrolone',
#  'DB00622': 'Nicardipine',
#  'DB00623': 'Fluphenazine',
#  'DB00624': 'Testosterone',
#  'DB00625': 'Efavirenz',
#  'DB00626': 'Bacitracin',
#  'DB00627': 'Niacin',
#  'DB00628': 'Clorazepic acid',
#  'DB00630': 'Alendronic acid',
#  'DB00631': 'Clofarabine',
#  'DB00633': 'Dexmedetomidine',
#  'DB00634': 'Sulfacetamide',
#  'DB00635': 'Prednisone',
#  'DB00637': 'Astemizole',
#  'DB00639': 'Butoconazole',
#  'DB00640': 'Adenosine',
#  'DB00641': 'Simvastatin',
#  'DB00642': 'Pemetrexed',
#  'DB00643': 'Mebendazole',
#  'DB00648': 'Mitotane',
#  'DB00649': 'Stavudine',
#  'DB00650': 'Leucovorin',
#  'DB00651': 'Dyphylline',
#  'DB00652': 'Pentazocine',
#  'DB00653': 'Magnesium sulfate',
#  'DB00654': 'Latanoprost',
#  'DB00656': 'Trazodone',
#  'DB00657': 'Mecamylamine',
#  'DB00658': 'Sevelamer',
#  'DB00660': 'Metaxalone',
#  'DB00661': 'Verapamil',
#  'DB00662': 'Trimethobenzamide',
#  'DB00665': 'Nilutamide',
#  'DB00666': 'Nafarelin',
#  'DB00668': 'Epinephrine',
#  'DB00669': 'Sumatriptan',
#  'DB00671': 'Cefixime',
#  'DB00672': 'Chlorpropamide',
#  'DB00673': 'Aprepitant',
#  'DB00674': 'Galantamine',
#  'DB00675': 'Tamoxifen',
#  'DB00677': 'Isoflurophate',
#  'DB00678': 'Losartan',
#  'DB00679': 'Thioridazine',
#  'DB00681': 'Amphotericin B',
#  'DB00682': 'Warfarin',
#  'DB00683': 'Midazolam',
#  'DB00684': 'Tobramycin',
#  'DB00686': 'Pentosan polysulfate',
#  'DB00687': 'Fludrocortisone',
#  'DB00688': 'Mycophenolate mofetil',
#  'DB00689': 'Cephaloglycin',
#  'DB00690': 'Flurazepam',
#  'DB00691': 'Moexipril',
#  'DB00692': 'Phentolamine',
#  'DB00694': 'Daunorubicin',
#  'DB00695': 'Furosemide',
#  'DB00696': 'Ergotamine',
#  'DB00697': 'Tizanidine',
#  'DB00698': 'Nitrofurantoin',
#  'DB00700': 'Eplerenone',
#  'DB00703': 'Methazolamide',
#  'DB00704': 'Naltrexone',
#  'DB00705': 'Delavirdine',
#  'DB00706': 'Tamsulosin',
#  'DB00707': 'Porfimer sodium',
#  'DB00708': 'Sufentanil',
#  'DB00709': 'Lamivudine',
#  'DB00710': 'Ibandronate',
#  'DB00712': 'Flurbiprofen',
#  'DB00713': 'Oxacillin',
#  'DB00714': 'Apomorphine',
#  'DB00715': 'Paroxetine',
#  'DB00717': 'Norethisterone',
#  'DB00718': 'Adefovir dipivoxil',
#  'DB00720': 'Clodronic acid',
#  'DB00721': 'Procaine',
#  'DB00722': 'Lisinopril',
#  'DB00723': 'Methoxamine',
#  'DB00724': 'Imiquimod',
#  'DB00726': 'Trimipramine',
#  'DB00727': 'Nitroglycerin',
#  'DB00728': 'Rocuronium',
#  'DB00730': 'Thiabendazole',
#  'DB00731': 'Nateglinide',
#  'DB00732': 'Atracurium besylate',
#  'DB00734': 'Risperidone',
#  'DB00736': 'Esomeprazole',
#  'DB00737': 'Meclizine',
#  'DB00738': 'Pentamidine',
#  'DB00739': 'Hetacillin',
#  'DB00740': 'Riluzole',
#  'DB00741': 'Hydrocortisone',
#  'DB00742': 'Mannitol',
#  'DB00743': 'Gadobenic acid',
#  'DB00744': 'Zileuton',
#  'DB00745': 'Modafinil',
#  'DB00746': 'Deferoxamine',
#  'DB00747': 'Scopolamine',
#  'DB00748': 'Carbinoxamine',
#  'DB00749': 'Etodolac',
#  'DB00750': 'Prilocaine',
#  'DB00752': 'Tranylcypromine',
#  'DB00753': 'Isoflurane',
#  'DB00754': 'Ethotoin',
#  'DB00755': 'Tretinoin',
#  'DB00756': 'Hexachlorophene',
#  'DB00757': 'Dolasetron',
#  'DB00758': 'Clopidogrel',
#  'DB00759': 'Tetracycline',
#  'DB00760': 'Meropenem',
#  'DB00761': 'Potassium chloride',
#  'DB00762': 'Irinotecan',
#  'DB00763': 'Methimazole',
#  'DB00764': 'Mometasone',
#  'DB00765': 'Metyrosine',
#  'DB00766': 'Clavulanic acid',
#  'DB00767': 'Benzquinamide',
#  'DB00768': 'Olopatadine',
#  'DB00769': 'Hydrocortamate',
#  'DB00770': 'Alprostadil',
#  'DB00771': 'Clidinium',
#  'DB00773': 'Etoposide',
#  'DB00774': 'Hydroflumethiazide',
#  'DB00775': 'Tirofiban',
#  'DB00776': 'Oxcarbazepine',
#  'DB00779': 'Nalidixic acid',
#  'DB00780': 'Phenelzine',
#  'DB00781': 'Polymyxin B',
#  'DB00782': 'Propantheline',
#  'DB00783': 'Estradiol',
#  'DB00784': 'Mefenamic acid',
#  'DB00787': 'Acyclovir',
#  'DB00788': 'Naproxen',
#  'DB00790': 'Perindopril',
#  'DB00794': 'Primidone',
#  'DB00795': 'Sulfasalazine',
#  'DB00796': 'Candesartan cilexetil',
#  'DB00798': 'Gentamicin',
#  'DB00801': 'Halazepam',
#  'DB00802': 'Alfentanil',
#  'DB00803': 'Colistin',
#  'DB00804': 'Dicyclomine',
#  'DB00806': 'Pentoxifylline',
#  'DB00808': 'Indapamide',
#  'DB00811': 'Ribavirin',
#  'DB00813': 'Fentanyl',
#  'DB00814': 'Meloxicam',
#  'DB00816': 'Orciprenaline',
#  'DB00818': 'Propofol',
#  'DB00819': 'Acetazolamide',
#  'DB00820': 'Tadalafil',
#  'DB00821': 'Carprofen',
#  'DB00822': 'Disulfiram',
#  'DB00823': 'Ethynodiol diacetate',
#  'DB00828': 'Fosfomycin',
#  'DB00829': 'Diazepam',
#  'DB00830': 'Phenmetrazine',
#  'DB00831': 'Trifluoperazine',
#  'DB00832': 'Phensuximide',
#  'DB00833': 'Cefaclor',
#  'DB00834': 'Mifepristone',
#  'DB00835': 'Brompheniramine',
#  'DB00836': 'Loperamide',
#  'DB00837': 'Progabide',
#  'DB00838': 'Clocortolone',
#  'DB00839': 'Tolazamide',
#  'DB00841': 'Dobutamine',
#  'DB00842': 'Oxazepam',
#  'DB00843': 'Donepezil',
#  'DB00844': 'Nalbuphine',
#  'DB00846': 'Flurandrenolide',
#  'DB00847': 'Cysteamine',
#  'DB00849': 'Methylphenobarbital',
#  'DB00850': 'Perphenazine',
#  'DB00851': 'Dacarbazine',
#  'DB00852': 'Pseudoephedrine',
#  'DB00853': 'Temozolomide',
#  'DB00854': 'Levorphanol',
#  'DB00855': 'Aminolevulinic acid',
#  'DB00857': 'Terbinafine',
#  'DB00859': 'Penicillamine',
#  'DB00860': 'Prednisolone',
#  'DB00861': 'Diflunisal',
#  'DB00862': 'Vardenafil',
#  'DB00863': 'Ranitidine',
#  'DB00864': 'Tacrolimus',
#  'DB00865': 'Benzphetamine',
#  'DB00867': 'Ritodrine',
#  'DB00869': 'Dorzolamide',
#  'DB00871': 'Terbutaline',
#  'DB00872': 'Conivaptan',
#  'DB00873': 'Loteprednol',
#  'DB00875': 'Flupentixol',
#  'DB00876': 'Eprosartan',
#  'DB00877': 'Sirolimus',
#  'DB00879': 'Emtricitabine',
#  'DB00880': 'Chlorothiazide',
#  'DB00881': 'Quinapril',
#  'DB00882': 'Clomifene',
#  'DB00883': 'Isosorbide dinitrate',
#  'DB00884': 'Risedronic acid',
#  'DB00887': 'Bumetanide',
#  'DB00888': 'Mechlorethamine',
#  'DB00889': 'Granisetron',
#  'DB00891': 'Sulfapyridine',
#  'DB00893': 'Iron Dextran',
#  'DB00895': 'Benzylpenicilloyl polylysine',
#  'DB00896': 'Rimexolone',
#  'DB00897': 'Triazolam',
#  'DB00898': 'Ethanol',
#  'DB00899': 'Remifentanil',
#  'DB00900': 'Didanosine',
#  'DB00903': 'Etacrynic acid',
#  'DB00904': 'Ondansetron',
#  'DB00905': 'Bimatoprost',
#  'DB00906': 'Tiagabine',
#  'DB00907': 'Cocaine',
#  'DB00908': 'Quinidine',
#  'DB00909': 'Zonisamide',
#  'DB00910': 'Paricalcitol',
#  'DB00911': 'Tinidazole',
#  'DB00912': 'Repaglinide',
#  'DB00915': 'Amantadine',
#  'DB00916': 'Metronidazole',
#  'DB00917': 'Dinoprostone',
#  'DB00918': 'Almotriptan',
#  'DB00919': 'Spectinomycin',
#  'DB00921': 'Buprenorphine',
#  'DB00923': 'Ceforanide',
#  'DB00924': 'Cyclobenzaprine',
#  'DB00925': 'Phenoxybenzamine',
#  'DB00927': 'Famotidine',
#  'DB00928': 'Azacitidine',
#  'DB00929': 'Misoprostol',
#  'DB00930': 'Colesevelam',
#  'DB00932': 'Tipranavir',
#  'DB00933': 'Mesoridazine',
#  'DB00934': 'Maprotiline',
#  'DB00935': 'Oxymetazoline',
#  'DB00937': 'Diethylpropion',
#  'DB00938': 'Salmeterol',
#  'DB00945': 'Aspirin',
#  'DB00946': 'Phenprocoumon',
#  'DB00948': 'Mezlocillin',
#  'DB00949': 'Felbamate',
#  'DB00950': 'Fexofenadine',
#  'DB00951': 'Isoniazid',
#  'DB00952': 'Naratriptan',
#  'DB00953': 'Rizatriptan',
#  'DB00955': 'Netilmicin',
#  'DB00956': 'Hydrocodone',
#  'DB00957': 'Norgestimate',
#  'DB00958': 'Carboplatin',
#  'DB00959': 'Methylprednisolone',
#  'DB00960': 'Pindolol',
#  'DB00961': 'Mepivacaine',
#  'DB00962': 'Zaleplon',
#  'DB00963': 'Bromfenac',
#  'DB00964': 'Apraclonidine',
#  'DB00965': 'Ethiodized oil',
#  'DB00966': 'Telmisartan',
#  'DB00967': 'Desloratadine',
#  'DB00968': 'Methyldopa',
#  'DB00969': 'Alosetron',
#  'DB00970': 'Dactinomycin',
#  'DB00972': 'Azelastine',
#  'DB00973': 'Ezetimibe',
#  'DB00974': 'Edetic acid',
#  'DB00975': 'Dipyridamole',
#  'DB00976': 'Telithromycin',
#  'DB00977': 'Ethinylestradiol',
#  'DB00979': 'Cyclopentolate',
#  'DB00980': 'Ramelteon',
#  'DB00981': 'Physostigmine',
#  'DB00982': 'Isotretinoin',
#  'DB00983': 'Formoterol',
#  'DB00984': 'Nandrolone phenpropionate',
#  'DB00985': 'Dimenhydrinate',
#  'DB00986': 'Glycopyrronium',
#  'DB00987': 'Cytarabine',
#  'DB00988': 'Dopamine',
#  'DB00989': 'Rivastigmine',
#  'DB00990': 'Exemestane',
#  'DB00991': 'Oxaprozin',
#  'DB00993': 'Azathioprine',
#  'DB00994': 'Neomycin',
#  'DB00996': 'Gabapentin',
#  'DB00997': 'Doxorubicin',
#  'DB00998': 'Frovatriptan',
#  'DB00999': 'Hydrochlorothiazide',
#  'DB01000': 'Cyclacillin',
#  'DB01001': 'Salbutamol',
#  'DB01002': 'Levobupivacaine',
#  'DB01003': 'Cromoglicic acid',
#  'DB01004': 'Ganciclovir',
#  'DB01005': 'Hydroxyurea',
#  'DB01006': 'Letrozole',
#  'DB01007': 'Tioconazole',
#  'DB01008': 'Busulfan',
#  'DB01009': 'Ketoprofen',
#  'DB01010': 'Edrophonium',
#  'DB01011': 'Metyrapone',
#  'DB01012': 'Cinacalcet',
#  'DB01013': 'Clobetasol propionate',
#  'DB01014': 'Balsalazide',
#  'DB01015': 'Sulfamethoxazole',
#  'DB01016': 'Glyburide',
#  'DB01017': 'Minocycline',
#  'DB01018': 'Guanfacine',
#  'DB01019': 'Bethanechol',
#  'DB01020': 'Isosorbide mononitrate',
#  'DB01021': 'Trichlormethiazide',
#  'DB01022': 'Vitamin K1',
#  'DB01023': 'Felodipine',
#  'DB01024': 'Mycophenolic acid',
#  'DB01026': 'Ketoconazole',
#  'DB01029': 'Irbesartan',
#  'DB01030': 'Topotecan',
#  'DB01032': 'Probenecid',
#  'DB01033': 'Mercaptopurine',
#  'DB01035': 'Procainamide',
#  'DB01036': 'Tolterodine',
#  'DB01037': 'Selegiline',
#  'DB01038': 'Carphenazine',
#  'DB01039': 'Fenofibrate',
#  'DB01041': 'Thalidomide',
#  'DB01042': 'Melphalan',
#  'DB01043': 'Memantine',
#  'DB01045': 'Rifampicin',
#  'DB01046': 'Lubiprostone',
#  'DB01047': 'Fluocinonide',
#  'DB01048': 'Abacavir',
#  'DB01049': 'Ergoloid mesylate',
#  'DB01050': 'Ibuprofen',
#  'DB01053': 'Benzylpenicillin',
#  'DB01054': 'Nitrendipine',
#  'DB01057': 'Echothiophate',
#  'DB01058': 'Praziquantel',
#  'DB01059': 'Norfloxacin',
#  'DB01060': 'Amoxicillin',
#  'DB01061': 'Azlocillin',
#  'DB01062': 'Oxybutynin',
#  'DB01063': 'Acetophenazine',
#  'DB01064': 'Isoprenaline',
#  'DB01065': 'Melatonin',
#  'DB01066': 'Cefditoren',
#  'DB01067': 'Glipizide',
#  'DB01068': 'Clonazepam',
#  'DB01069': 'Promethazine',
#  'DB01070': 'Dihydrotachysterol',
#  'DB01071': 'Mequitazine',
#  'DB01072': 'Atazanavir',
#  'DB01073': 'Fludarabine',
#  'DB01074': 'Perhexiline',
#  'DB01075': 'Diphenhydramine',
#  'DB01076': 'Atorvastatin',
#  'DB01080': 'Vigabatrin',
#  'DB01081': 'Diphenoxylate',
#  'DB01082': 'Streptomycin',
#  'DB01083': 'Orlistat',
#  'DB01085': 'Pilocarpine',
#  'DB01086': 'Benzocaine',
#  'DB01087': 'Primaquine',
#  'DB01088': 'Iloprost',
#  'DB01093': 'Dimethyl sulfoxide',
#  'DB01095': 'Fluvastatin',
#  'DB01097': 'Leflunomide',
#  'DB01098': 'Rosuvastatin',
#  'DB01099': 'Flucytosine',
#  'DB01100': 'Pimozide',
#  'DB01101': 'Capecitabine',
#  'DB01103': 'Quinacrine',
#  'DB01104': 'Sertraline',
#  'DB01106': 'Levocabastine',
#  'DB01109': 'Heparin',
#  'DB01110': 'Miconazole',
#  'DB01111': 'Colistimethate',
#  'DB01112': 'Cefuroxime',
#  'DB01113': 'Papaverine',
#  'DB01114': 'Chlorpheniramine',
#  'DB01115': 'Nifedipine',
#  'DB01117': 'Atovaquone',
#  'DB01118': 'Amiodarone',
#  'DB01119': 'Diazoxide',
#  'DB01120': 'Gliclazide',
#  'DB01124': 'Tolbutamide',
#  'DB01126': 'Dutasteride',
#  'DB01127': 'Econazole',
#  'DB01128': 'Bicalutamide',
#  'DB01129': 'Rabeprazole',
#  'DB01130': 'Prednicarbate',
#  'DB01131': 'Proguanil',
#  'DB01132': 'Pioglitazone',
#  'DB01133': 'Tiludronic acid',
#  'DB01136': 'Carvedilol',
#  'DB01137': 'Levofloxacin',
#  'DB01138': 'Sulfinpyrazone',
#  'DB01139': 'Cefapirin',
#  'DB01140': 'Cefadroxil',
#  'DB01142': 'Doxepin',
#  'DB01143': 'Amifostine',
#  'DB01144': 'Diclofenamide',
#  'DB01145': 'Sulfoxone',
#  'DB01147': 'Cloxacillin',
#  'DB01148': 'Flavoxate',
#  'DB01149': 'Nefazodone',
#  'DB01150': 'Cefprozil',
#  'DB01151': 'Desipramine',
#  'DB01155': 'Gemifloxacin',
#  'DB01156': 'Bupropion',
#  'DB01158': 'Bretylium',
#  'DB01159': 'Halothane',
#  'DB01161': 'Chloroprocaine',
#  'DB01162': 'Terazosin',
#  'DB01163': 'Amdinocillin',
#  'DB01164': 'Calcium chloride',
#  'DB01165': 'Ofloxacin',
#  'DB01166': 'Cilostazol',
#  'DB01167': 'Itraconazole',
#  'DB01168': 'Procarbazine',
#  'DB01169': 'Arsenic trioxide',
#  'DB01171': 'Moclobemide',
#  'DB01172': 'Kanamycin',
#  'DB01173': 'Orphenadrine',
#  'DB01174': 'Phenobarbital',
#  'DB01175': 'Escitalopram',
#  'DB01176': 'Cyclizine',
#  'DB01177': 'Idarubicin',
#  'DB01178': 'Chlormezanone',
#  'DB01181': 'Ifosfamide',
#  'DB01182': 'Propafenone',
#  'DB01183': 'Naloxone',
#  'DB01184': 'Domperidone',
#  'DB01185': 'Fluoxymesterone',
#  'DB01189': 'Desflurane',
#  'DB01190': 'Clindamycin',
#  'DB01192': 'Oxymorphone',
#  'DB01193': 'Acebutolol',
#  'DB01194': 'Brinzolamide',
#  'DB01195': 'Flecainide',
#  'DB01196': 'Estramustine',
#  'DB01197': 'Captopril',
#  'DB01198': 'Zopiclone',
#  'DB01200': 'Bromocriptine',
#  'DB01201': 'Rifapentine',
#  'DB01202': 'Levetiracetam',
#  'DB01203': 'Nadolol',
#  'DB01204': 'Mitoxantrone',
#  'DB01205': 'Flumazenil',
#  'DB01206': 'Lomustine',
#  'DB01207': 'Ridogrel',
#  'DB01208': 'Sparfloxacin',
#  'DB01210': 'Levobunolol',
#  'DB01211': 'Clarithromycin',
#  'DB01212': 'Ceftriaxone',
#  'DB01214': 'Metipranolol',
#  'DB01215': 'Estazolam',
#  'DB01217': 'Anastrozole',
#  'DB01218': 'Halofantrine',
#  'DB01219': 'Dantrolene',
#  'DB01220': 'Rifaximin',
#  'DB01221': 'Ketamine',
#  'DB01222': 'Budesonide',
#  'DB01223': 'Aminophylline',
#  'DB01224': 'Quetiapine',
#  'DB01225': 'Enoxaparin',
#  'DB01229': 'Paclitaxel',
#  'DB01232': 'Saquinavir',
#  'DB01233': 'Metoclopramide',
#  'DB01234': 'Dexamethasone',
#  'DB01235': 'Levodopa',
#  'DB01236': 'Sevoflurane',
#  'DB01238': 'Aripiprazole',
#  'DB01239': 'Chlorprothixene',
#  'DB01240': 'Epoprostenol',
#  'DB01241': 'Gemfibrozil',
#  'DB01242': 'Clomipramine',
#  'DB01244': 'Bepridil',
#  'DB01247': 'Isocarboxazid',
#  'DB01248': 'Docetaxel',
#  'DB01249': 'Iodixanol',
#  'DB01250': 'Olsalazine',
#  'DB01251': 'Gliquidone',
#  'DB01253': 'Ergometrine',
#  'DB01254': 'Dasatinib',
#  'DB01255': 'Lisdexamfetamine',
#  'DB01256': 'Retapamulin',
#  'DB01257': 'Eculizumab',
#  'DB01259': 'Lapatinib',
#  'DB01260': 'Desonide',
#  'DB01261': 'Sitagliptin',
#  'DB01262': 'Decitabine',
#  'DB01263': 'Posaconazole',
#  'DB01264': 'Darunavir',
#  'DB01265': 'Telbivudine',
#  'DB01267': 'Paliperidone',
#  'DB01268': 'Sunitinib',
#  'DB01269': 'Panitumumab',
#  'DB01270': 'Ranibizumab',
#  'DB01273': 'Varenicline',
#  'DB01274': 'Arformoterol',
#  'DB01275': 'Hydralazine',
#  'DB01276': 'Exenatide',
#  'DB01277': 'Mecasermin',
#  'DB01278': 'Pramlintide',
#  'DB01280': 'Nelarabine',
#  'DB01281': 'Abatacept',
#  'DB01282': 'Carbetocin',
#  'DB01284': 'Tetracosactide',
#  'DB01285': 'Corticotropin',
#  'DB01288': 'Fenoterol',
#  'DB01291': 'Pirbuterol',
#  'DB01294': 'Bismuth subsalicylate',
#  'DB01296': 'Glucosamine',
#  'DB01298': 'Sulfacytine',
#  'DB01306': 'Insulin aspart',
#  'DB01307': 'Insulin detemir',
#  'DB01309': 'Insulin glulisine',
#  'DB01319': 'Fosamprenavir',
#  'DB01320': 'Fosphenytoin',
#  'DB01323': "St. John's Wort",
#  'DB01326': 'Cefamandole',
#  'DB01327': 'Cefazolin',
#  'DB01328': 'Cefonicid',
#  'DB01329': 'Cefoperazone',
#  'DB01330': 'Cefotetan',
#  'DB01331': 'Cefoxitin',
#  'DB01332': 'Ceftizoxime',
#  'DB01333': 'Cefradine',
#  'DB01337': 'Pancuronium',
#  'DB01339': 'Vecuronium',
#  'DB01340': 'Cilazapril',
#  'DB01344': 'Tolevamer',
#  'DB01351': 'Amobarbital',
#  'DB01353': 'Butobarbital',
#  'DB01354': 'Heptabarbital',
#  'DB01355': 'Hexobarbital',
#  'DB01356': 'Lithium cation',
#  'DB01357': 'Mestranol',
#  'DB01359': 'Penbutolol',
#  'DB01362': 'Iohexol',
#  'DB01363': 'Ephedra',
#  'DB01364': 'Ephedrine',
#  'DB01365': 'Mephentermine',
#  'DB01367': 'Rasagiline',
#  'DB01369': 'Quinupristin',
#  'DB01377': 'Magnesium oxide',
#  'DB01380': 'Cortisone acetate',
#  'DB01381': 'Ginkgo biloba',
#  'DB01390': 'Sodium bicarbonate',
#  'DB01392': 'Yohimbine',
#  ...}

# %%
# Import raw drugbank dataset
df_db_int = pd.read_csv("data/ChCh-Miner_durgbank-chem-chem.tsv", sep='\t', header=None)
df_db_int.columns = ['drug_1_code', 'drug_2_code']

# Perform code-name mapping
df_db_int['drug_1_name'] = df_db_int['drug_1_code'].map(db_mapping)
df_db_int['drug_2_name'] = df_db_int['drug_2_code'].map(db_mapping)

new_cols = ['drug_1_code', 'drug_1_name', 'drug_2_code', 'drug_2_name']
df_db_int = df_db_int[new_cols]
df_db_int.head()
# Out:
#   drug_1_code   drug_1_name drug_2_code     drug_2_name
# 0     DB00862    Vardenafil     DB00966     Telmisartan
# 1     DB00575     Clonidine     DB00806  Pentoxifylline
# 2     DB01242  Clomipramine     DB08893      Mirabegron
# 3     DB01151   Desipramine     DB08883      Perampanel
# 4     DB01235      Levodopa     DB01275     Hydralazine

# %% [markdown]
# #### 2(b) Polypharmacy side effects

# %%
# Read CID mapping JSON
with open('data/CID_mapping.json', 'r') as fp:
    cid_mapping = json.load(fp)
    
cid_mapping
# Out:
# {'CID000002173': '6-{[Amino(phenyl)acetyl]amino}-3,3-dimethyl-7-oxo-4-thia-1-azabicyclo[3.2.0]heptane-2-carboxylate',
#  'CID000005206': 'Sevoflurane',
#  'CID000003929': 'N-[[(5S)-3-[3-Fluoro-4-(4-morpholinyl)phenyl]-2-oxo-5-oxazolidinyl]methyl]-acetamide',
#  'CID000001302': '2-(6-Methoxy-2-naphthyl)propionic acid',
#  'CID000005267': 'Duraspiron',
#  'CID000004601': 'Orphenadrine',
#  'CID000005090': 'Rofecoxib',
#  'CID000004946': 'Propranolol',
#  'CID000005391': 'Temazepam',
#  'CID000002802': 'Clonazepam',
#  'CID000004212': 'Mitoxantrone',
#  'CID000000596': 'Depocyt',
#  'CID000002522': '5-[2-[1-(5-Cyclopropyl-5-hydroxypent-3-en-2-yl)-7a-methyl-2,3,3a,5,6,7-hexahydro-1H-inden-4-ylidene]ethylidene]-4-methylenecyclohexane-1,3-diol',
#  'CID000003405': 'CID 3405',
#  'CID000003446': 'Gabapentin',
#  'CID000004107': 'Methocarbamol',
#  'CID000003161': 'CID 3161',
#  'CID000003823': 'Ketoconazole',
#  'CID000005556': 'Triazolam',
#  'CID000002156': '[2-[4-[(2-Butylbenzofuran-3-yl)carbonyl]-2,6-diiodophenoxy]ethyl]diethylaminium',
#  'CID000002907': 'Cyclophosphamide',
#  'CID000004192': 'Midazolam',
#  'CID000000838': 'Adrenaline',
#  'CID000001986': 'Acetazolamide',
#  'CID000004920': '(8S,9S,10R,13S,14S,17S)-17-Acetyl-10,13-dimethyl-1,2,6,7,8,9,11,12,14,15,16,17-dodecahydrocyclopenta[a]phenanthren-3-one',
#  'CID000005478': '1-(Tert-butylamino)-3-{[4-(morpholin-4-yl)-1,2,5-thiadiazol-3-yl]oxy}propan-2-ol',
#  'CID000003937': 'N~2~-(1-Carboxy-3-phenylpropyl)lysylproline',
#  'CID000004158': 'Methylphenidate',
#  'CID000003696': 'Imipramine',
#  'CID000003899': 'Leflunomide',
#  'CID000000853': 'DL-Thyroxine',
#  'CID000003826': 'Ketorolac',
#  'CID000003143': 'Docetaxeltrihydrate',
#  'CID000004736': 'Talwin',
#  'CID000005005': '3-Isoquinolinecarboxylic acid, 2-(2-((1-(ethoxycarbonyl)-3-phenylpropyl)amino)-1-oxopropyl)-1,2,3,4-tetrahydro-',
#  'CID000003261': 'Estazolam',
#  'CID000002162': 'Amlodipine',
#  'CID000004259': '1-Cyclopropyl-6-fluoro-8-methoxy-7-(octahydro-6h-pyrrolo[3,4-b]pyridin-6-yl)-4-oxo-1,4-dihydroquinoline-3-carboxylic acid',
#  'CID000003957': 'Loratadine',
#  'CID000004595': 'Ondansetron',
#  'CID000002666': '7-{[Amino(phenyl)acetyl]amino}-3-methyl-8-oxo-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylic acid',
#  'CID000003007': 'Amphetamine',
#  'CID000003559': 'Haloperidol',
#  'CID000004909': 'Primidone',
#  'CID000002520': 'Verapamil',
#  'CID000004889': '3,5-Dihydroxy-7-[6-hydroxy-2-methyl-8-(2-methyl-1-oxobutoxy)-1,2,6,7,8,8a-hexahydronaphthalen-1-yl]heptanoic acid',
#  'CID000003958': 'Lorazepam',
#  'CID000005505': 'Tolbutamide',
#  'CID000038904': 'Carboplatinum',
#  'CID000004485': 'Nifedipine',
#  'CID000005245': 'Risedronic acid',
#  'CID000039765': 'Vecuronium',
#  'CID000004635': 'Percodan',
#  'CID000002554': 'Carbamazepine',
#  'CID000002650': 'Ceftazidim',
#  'CID000003749': 'Irbesartan',
#  'CID000003440': 'Furosemide',
#  'CID000002909': 'Cyclosporin',
#  'CID000003075': '2-[3-Acetyloxy-2-(4-methoxyphenyl)-4-oxo-2,3-dihydro-1,5-benzothiazepin-5-yl]ethyl-dimethylazanium',
#  'CID000005647': 'CID 5647',
#  'CID000003386': 'Fluoxetine',
#  'CID000000271': 'Calcium ion',
#  'CID000003016': 'Diazepam',
#  'CID000003750': "4,11-Diethyl-4-hydroxy-3,14-dioxo-3,4,12,14-tetrahydro-1H-pyrano[3',4':6,7]indolizino[1,2-b]quinolin-9-yl 1,4'-bipiperidine-1'-carboxylate",
#  'CID000004173': 'Metronidazole',
#  'CID000004159': 'A-Methapred',
#  'CID000001065': "6'-Methoxycinchonan-9-ol",
#  'CID000002576': 'Carisoprodol',
#  'CID000002541': 'Candesartan',
#  'CID000004543': 'Nortriptyline',
#  'CID000004917': 'Prochlorperazine',
#  'CID000003640': '11,17,21-Trihydroxypregn-4-ene-3,20-dione',
#  'CID000060831': '3-Oxa-9-azoniatricyclo[3.3.1.02,4]nonane,7-[(2-hydroxy-2,2-di-2-thienylacetyl)oxy]-9,9-dimethyl-, (1a,2b,4b,5a,7b)-',
#  'CID000002022': 'CID 2022',
#  'CID000000206': 'Hexose',
#  'CID000003793': 'Sporanox',
#  'CID000000450': '13-Methyl-6,7,8,9,11,12,14,15,16,17-decahydrocyclopenta[a]phenanthrene-3,17-diol',
#  'CID000002756': 'Cimetidine',
#  'CID000003657': 'Hydroxyurea',
#  'CID000003890': '15(S)-Latanoprost',
#  'CID000002088': 'Alendronic acid',
#  'CID000004034': 'Meclizine',
#  'CID000002891': 'Cobalt(2+);[5-(5,6-dimethylbenzimidazol-1-yl)-4-hydroxy-2-(hydroxymethyl)oxolan-3-yl] 1-[3-[2,13,18-tris(2-amino-2-oxoethyl)-7,12,17-tris(3-amino-3-oxopropyl)-3,5,8,8,13,15,18,19-octamethyl-2,7,12,17-tetrahydro-1H-corrin-21-id-3-yl]propanoylamino]propan-2-yl hydrogen phosphate;cyanide',
#  'CID000002585': 'Carvedilol',
#  'CID000005358': 'Sumatriptan',
#  'CID000005234': 'Sodium chloride',
#  'CID000002578': 'Carmustine',
#  'CID000005038': 'Unipril',
#  'CID000002118': 'Alprazolam',
#  'CID000003715': 'Indomethacin',
#  'CID000004264': '9-[4-[3,4-Dihydroxy-5-[[3-(3-hydroxybutan-2-yl)oxiran-2-yl]methyl]oxan-2-yl]-3-methylbut-2-enoyl]oxynonanoic acid',
#  'CID000003062': 'Lanicor',
#  'CID000003825': 'Ketoprofen',
#  'CID000002487': 'Torbugesic',
#  'CID000000214': '7-[3-Hydroxy-2-(3-hydroxyoct-1-enyl)-5-oxocyclopentyl]heptanoic acid',
#  'CID000002405': 'Bisoprolol',
#  'CID000003648': 'Morphinan-6-one, 4,5alpha-epoxy-3-hydroxy-17-methyl-',
#  'CID000000772': 'Heparin',
#  'CID000003365': 'Fluconazole',
#  'CID000002609': 'Lilly 99638',
#  'CID000002656': '7-[[2-(2-Amino-1,3-thiazol-4-yl)-2-methoxyiminoacetyl]amino]-3-[(2-methyl-6-oxido-5-oxo-1,2,4-triazin-3-yl)sulfanylmethyl]-8-oxo-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylate',
#  'CID000005523': 'Ultram',
#  'CID000003661': 'L-Hyoscyamine',
#  'CID000003308': 'Etodolac',
#  'CID000005203': '4-(3,4-Dichlorophenyl)-n-methyl-1,2,3,4-tetrahydronaphthalen-1-amine',
#  'CID000004201': 'Minoxidil',
#  'CID000003043': 'CID 3043',
#  'CID000004509': '1-[(5-Nitro-2-furanyl)methylideneamino]imidazolidine-2,4-dione',
#  'CID000003222': '1-(2-{[1-(Ethoxycarbonyl)-3-phenylpropyl]amino}propanoyl)proline maleate',
#  'CID000005040': '(RS)-rapamycin',
#  'CID000003404': '2-[[5-Methoxy-1-[4-(trifluoromethyl)phenyl]pentylidene]amino]oxyethanamine',
#  'CID000004679': 'Pantoprazole',
#  'CID000060147': '(+)-Tamsulosin',
#  'CID000005077': 'Exelon',
#  'CID000003878': 'Lamotrigine',
#  'CID000002244': 'Aspirin',
#  'CID000003345': 'Fentanyl',
#  'CID000027661': 'Isosorbide mononitrate',
#  'CID000004054': 'Memantine',
#  'CID000003911': 'Leuprelin Acetate',
#  'CID000003348': 'Fexofenadine',
#  'CID000002771': 'Citalopram',
#  'CID000003279': 'Etambutol',
#  'CID000004253': 'Nepenthe',
#  'CID000003333': 'Felodipine',
#  'CID000060795': 'Aripiprazole',
#  'CID000000453': 'Hexitol',
#  'CID000000159': '5-[5-Hydroxy-4-(3-hydroxyoct-1-enyl)-3,3a,4,5,6,6a-hexahydrocyclopenta[b]furan-2-ylidene]pentanoic acid',
#  'CID000003419': '4-Cyclohexyl-1-[2-[(2-methyl-1-propanoyloxypropoxy)-(4-phenylbutyl)phosphoryl]acetyl]pyrrolidine-2-carboxylate',
#  'CID000005533': 'Trazodone',
#  'CID000005379': 'Gatifloxacin',
#  'CID000005039': 'Ranisen',
#  'CID000003463': 'Gemfibrozil',
#  'CID000000598': '2-Mercaptoethanesulfonic acid',
#  'CID000002284': 'Baclofen',
#  'CID000002662': 'Celecoxib',
#  'CID003085017': 'Sevelamer',
#  'CID000004829': 'Pioglitazone',
#  'CID000003385': '5-Fluorouracil',
#  'CID000003203': 'Rac-Efavirenz',
#  'CID000003954': 'Loperamide(1+)',
#  'CID000002153': 'Theophylline',
#  'CID000005152': 'Salmeterol',
#  'CID000005645': '3,7-Dihydroxycholan-24-oic acid',
#  'CID000005717': 'Zafirlukast',
#  'CID000002726': 'Chlorpromazine',
#  'CID000004999': 'Quazepam',
#  'CID000004547': '2-Ethoxy-4-[2-[[3-methyl-1-(2-piperidin-1-ylphenyl)butyl]amino]-2-oxoethyl]benzoic acid',
#  'CID000002471': 'Bumetanide',
#  'CID000003305': 'Etidronic acid',
#  'CID000002806': 'Clopidogrelum',
#  'CID000002631': '3-(Acetyloxymethyl)-7-[[2-(2-amino-1,3-thiazol-4-yl)-2-methoxyiminoacetyl]amino]-8-oxo-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylate',
#  'CID000003410': 'Formoterol',
#  'CID000003449': 'Epigalanthamin',
#  'CID000002083': 'Salbutamol',
#  'CID000001690': '3,5,12-Trihydroxy-3-(hydroxyacetyl)-10-methoxy-6,11-dioxo-1,2,3,4,6,11-hexahydrotetracen-1-yl 3-ammonio-2,3,6-trideoxyhexopyranoside',
#  'CID000002617': '3-{[(5-Methyl-1,3,4-thiadiazol-2-yl)sulfanyl]methyl}-8-oxo-7-[(1H-tetrazol-1-ylacetyl)amino]-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylate',
#  'CID000005731': '2-Oxazolidinone, 4-[[3-[2-(dimethylamino)ethyl]-1H-indol-5-yl]methyl]-',
#  'CID000004046': 'Mefloquine',
#  'CID000001972': '3-(4-Amino-3,5-dihydroxy-6-methyloxan-2-yl)oxy-19,25,27,30,31,33,35,37-octahydroxy-18,20,21-trimethyl-23-oxo-22,39-dioxabicyclo[33.3.1]nonatriaconta-4,6,8,10,12,14,16-heptaene-38-carboxylic acid',
#  'CID000004900': 'delta-E',
#  'CID000003152': 'Donepezil',
#  'CID000000444': 'Bupropion',
#  'CID000005726': 'Aztec',
#  'CID000004585': 'CID 4585',
#  'CID000005078': 'Rizatriptan',
#  'CID000041693': 'Sufentanil',
#  'CID000005372': '8-Epi Tacrolimus',
#  'CID000003961': 'Losartan',
#  'CID000004691': '3-(1,3-Benzodioxol-5-yloxymethyl)-4-(4-fluorophenyl)piperidine',
#  'CID000004594': 'Omeprazole',
#  'CID000004927': 'Promethazine',
#  'CID000004091': 'Metformin',
#  'CID000001117': 'Sulfate',
#  'CID000005076': 'N-[3-Hydroxy-5-[[3-methyl-2-[[[methyl-[(2-propan-2-yl-4-thiazolyl)methyl]amino]-oxomethyl]amino]-1-oxobutyl]amino]-1,6-diphenylhexan-2-yl]carbamic acid 5-thiazolylmethyl ester',
#  'CID000003355': '[2,5-Bis(2,2,2-trifluoroethoxy)benzoyl]-(piperidin-2-ylmethyl)azanium',
#  'CID000004112': 'Amethopterin',
#  'CID000005412': 'CID 5412',
#  'CID000003108': 'Dipyridamole',
#  'CID000002250': '7-[4-[Anilino(oxo)methyl]-2-(4-fluorophenyl)-3-phenyl-5-propan-2-yl-1-pyrrolyl]-3,5-dihydroxyheptanoic acid',
#  'CID000002265': 'Azathioprine',
#  'CID000002801': 'Clomipramine',
#  'CID000059708': 'Etiracetam',
#  'CID000003877': '4-Amino-1-((2S,5R)-2-(hydroxymethyl)-1,3-oxathiolan-5-yl)pyrimidin-2(1H)-one',
#  'CID000002749': 'Ciclopirox',
#  'CID000002720': 'Chlorothiazide',
#  'CID000003639': 'Hydrochlorothiazide',
#  'CID000004634': 'Oxybutynin',
#  'CID000002764': 'Ciprofloxacin',
#  'CID000000942': '3-(1-Methylpyrrolidin-2-yl)pyridine',
#  'CID000004211': 'Mitotane',
#  'CID000004170': 'Metolazone',
#  'CID000003746': 'Atrovent',
#  'CID000003042': 'Dicyclomine',
#  'CID000001206': 'DL-Methamphetamine',
#  'CID000004609': '(2-Azanidylcyclohexyl)azanide;oxalic acid;platinum(2+)',
#  'CID000004411': 'Solgol',
#  'CID000004138': '3-Hydroxy-alpha-methyl-DL-tyrosine',
#  'CID000005212': 'CID 5212',
#  'CID000002311': '2-[3-[(1-Ethoxy-1-oxo-4-phenylbutan-2-yl)amino]-2-oxo-4,5-dihydro-3H-1-benzazepin-1-yl]acetic acid',
#  'CID000003148': 'Anzemet',
#  'CID000083786': 'CID 83786',
#  'CID000001775': 'Phenytoin',
#  'CID000003767': 'Isoniazid',
#  'CID000002658': '3-(Carbamoyloxymethyl)-7-[[2-(furan-2-yl)-2-methoxyiminoacetyl]amino]-8-oxo-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylate',
#  'CID000054454': 'Simvastatin',
#  'CID000000861': 'Rathyronine',
#  'CID000003255': 'Ilotycin',
#  'CID000005512': '2-(3-(Diisopropylamino)-1-phenylpropyl)-4-methylphenol',
#  'CID000003672': 'Ibuprofen',
#  'CID000002550': '1-(2-Methyl-3-sulfanylpropanoyl)pyrrolidine-2-carboxylic acid',
#  'CID000003032': 'Voltaren',
#  'CID000002187': 'Anastrozole',
#  'CID000002267': 'Azelastine',
#  'CID000005514': 'Topiramate-13C6',
#  'CID000001546': 'Leustat',
#  'CID000041781': 'Torsemide',
#  'CID000002249': 'Atenolol',
#  'CID000004599': '1-(3-Hexyl-4-oxooxetan-2-yl)tridecan-2-yl 2-formamido-4-methylpentanoate',
#  'CID000003488': 'Glyburide',
#  'CID000002951': 'Dantrolene(1-)',
#  'CID000004740': 'Pentoxifylline',
#  'CID000002092': 'Alfuzosin',
#  'CID000005253': 'Sotalol',
#  'CID000003249': '3-[2-[1-(5,6-Dimethylhept-3-en-2-yl)-7a-methyl-2,3,3a,5,6,7-hexahydro-1H-inden-4-ylidene]ethylidene]-4-methylidenecyclohexan-1-ol',
#  'CID000003690': 'Ifosfamide',
#  'CID000003883': 'Lansoprazole',
#  'CID000004510': 'Nitroglycerin',
#  'CID000002678': 'Cetirizine',
#  'CID000002818': 'CID 2818',
#  'CID000065999': 'Telmisartan',
#  'CID000002462': 'Rhinocort',
#  'CID000002895': 'Cyclobenzaprine',
#  'CID000008953': 'CID 8953',
#  'CID000002435': 'Brimonidine',
#  'CID000003325': 'Famotidine',
#  'CID000003003': 'Celestone',
#  'CID000003379': 'Nasalide',
#  'CID000002812': 'Clotrimazole',
#  'CID000003516': 'Guaifenesin',
#  'CID000002524': '1,25-Dihydroxyvitamin D3',
#  'CID000003706': '1-[4-Benzyl-2-hydroxy-5-[(2-hydroxy-2,3-dihydro-1H-inden-1-yl)amino]-5-oxopentyl]-N-tert-butyl-4-(pyridin-3-ylmethyl)piperazine-2-carboxamide',
#  'CID000060865': '2-[11-[3-(Dimethylamino)propylidene]-6H-benzo[c][1]benzoxepin-2-yl]acetic acid',
#  'CID000003478': 'Glipizide',
#  'CID000003367': 'Fludarabine Base',
#  'CID000005656': 'Venlafaxine',
#  'CID000002803': 'Clonidine',
#  'CID000005401': 'Terazosin',
#  'CID000062924': 'S-(Fluoromethyl) (6S,9R,10S,11S,13S,14S,16R,17R)-6,9-difluoro-11,17-dihydroxy-10,13,16-trimethyl-3-oxo-6,7,8,11,12,14,15,16-octahydrocyclopenta[a]phenanthrene-17-carbothioate',
#  'CID000004943': 'Propofol',
#  'CID000000581': 'N-Acetyl-DL-cysteine',
#  'CID000004052': 'CID 4052',
#  'CID000068844': 'Brinzolamide',
#  'CID000005732': 'Zolpidem',
#  'CID000004409': 'Nabumetone',
#  'CID000004812': '2-Methyl-3-(3,7,11,15-tetramethylhexadec-2-enyl)naphthalene-1,4-dione',
#  'CID000003310': "4'-Demethylepipodophyllotoxin 9-(4,6-O-ethylidene-beta-D-glucopyranoside)",
#  'CID000005073': 'Risperidone',
#  'CID000003510': 'Granisetron',
#  'CID000125889': '(3R)-3-(Aminomethyl)-5-methylhexanoic acid',
#  'CID000003350': '4-Azaandrost-1-ene-17-carboxamide, N-(1,1-dimethylethyl)-3-oxo-, (5alpha,17beta)-',
#  'CID000003962': 'Monacolin K',
#  'CID000004885': 'N6-Propyl-4,5,6,7-tetrahydro-1,3-benzothiazole-2,6-diamine',
#  'CID000003658': 'Hydroxyzine',
#  'CID000004189': 'Miconazole',
#  'CID000005291': 'Imatinib',
#  'CID000002978': 'delta9-Tetrahydrocannabinol',
#  'CID000003339': 'Fenofibrate',
#  'CID000002476': '[5alpha,7alpha(S)]-17-(Cyclopropylmethyl)-alpha-(1,1-dimethylethyl)-4,5-epoxy-18,19-dihydro-3-hydroxy-6-methoxy-alpha-methyl-6,14-ethenomorphinan-7-methanol',
#  'CID000003652': 'Hydroxychloroquine',
#  'CID000072054': '2-(1-(2-(2,3-Dihydrobenzofuran-5-yl)ethyl)pyrrolidin-3-yl)-2,2-diphenylacetamide',
#  'CID000002308': 'Pregna-1,4-diene-3,20-dione, 9-chloro-11,17,21-trihydroxy-16-methyl-, (11beta,16beta)-',
#  'CID000000143': 'CID 143',
#  'CID000002786': 'Cleocin',
#  'CID000003676': 'Lidocaine',
#  'CID000001071': '9-cis Retinol',
#  'CID000004513': 'Axid Ar',
#  'CID000016231': 'Amiloride',
#  'CID000004894': '11,17,21-Trihydroxypregna-1,4-diene-3,20-dione',
#  'CID000003393': 'Flurazepam',
#  'CID000005735': 'Zopiclone',
#  'CID000003154': '4-(Ethylamino)-6-methyl-5,6-dihydro-4h-thieno[2,3-b]thiopyran-2-sulfonamide 7,7-dioxide',
#  'CID000000191': '2-(6-Aminopurin-9-yl)-5-(hydroxymethyl)oxolane-3,4-diol',
#  'CID000002477': 'Buspirone',
#  'CID000006691': 'CID 6691',
#  'CID000000937': 'Nicotinate',
#  'CID000004723': 'Pemoline',
#  'CID000002955': 'Dapsone',
#  'CID000002160': 'Amitriptyline',
#  'CID000003008': 'Racemethorphan',
#  'CID000003158': 'Doxepin',
#  'CID000003157': 'Doxazosin',
#  'CID000003324': 'Famciclovir',
#  'CID000004171': 'Metoprolol',
#  'CID000004583': 'Ofloxacin',
#  'CID000005538': '3,7-Dimethyl-9-(2,6,6-trimethylcyclohex-1-en-1-yl)nona-2,4,6,8-tetraenoic acid',
#  'CID000003168': 'Droperidol',
#  'CID000003476': 'Glimepiride',
#  'CID000004536': '17-Ethynyl-17-hydroxyestr-4-en-3-one',
#  'CID000002474': 'Bupivacaine',
#  'CID000002171': '6-{[Amino(4-hydroxyphenyl)acetyl]amino}-3,3-dimethyl-7-oxo-4-thia-1-azabicyclo[3.2.0]heptane-2-carboxylic acid',
#  'CID000004200': 'CID 4200',
#  'CID000003736': 'Iopromide',
#  'CID000005487': 'Tizanidine',
#  'CID000000815': '(2R,3S,4S,5R,6R)-2-(Aminomethyl)-6-[(1R,2R,3S,4R,6S)-4,6-diamino-3-[(2S,3R,4S,5S,6R)-4-amino-3,5-dihydroxy-6-(hydroxymethyl)oxan-2-yl]oxy-2-hydroxycyclohexyl]oxyoxane-3,4,5-triol',
#  'CID000005544': 'Mycolog',
#  'CID000005496': 'Nebramycin factor 6',
#  'CID000005672': 'Vinorelbine base',
#  'CID000003403': '7-[3-(4-Fluorophenyl)-1-propan-2-yl-2-indolyl]-3,5-dihydroxy-6-heptenoic acid',
#  'CID000004236': 'Modafinil',
#  'CID000004614': 'Oxaprozin',
#  'CID000004168': 'Metoclopramide',
#  'CID000003902': 'Letrozole',
#  'CID000003780': 'D-Glucitol, 1,4:3,6-dianhydro-, dinitrate',
#  'CID000005402': 'N,6,6-Trimethyl-N-(1-naphthalenylmethyl)-1-hept-2-en-4-ynamine',
#  'CID000005002': 'Quetiapine',
#  'CID000004463': 'Nevirapine',
#  'CID000001971': '[4-[2-Amino-6-(cyclopropylamino)purin-9-yl]cyclopent-2-en-1-yl]methanol',
#  'CID000005426': 'Thalidomide',
#  'CID000154059': 'Solifenacin',
#  'CID000004873': 'Potassium chloride',
#  'CID000002269': '2-Ethyl-3,4,10-trihydroxy-3,5,6,8,10,12,14-heptamethyl-15-oxo-11-{[3,4,6-trideoxy-3-(dimethylamino)hexopyranosyl]oxy}-1-oxa-6-azacyclopentadecan-13-yl 2,6-dideoxy-3-C-methyl-3-O-methylhexopyranoside',
#  'CID000005064': '1-[3,4-Dihydroxy-5-(hydroxymethyl)-2-oxolanyl]-1,2,4-triazole-3-carboxamide',
#  'CID000004419': 'Morphinan-3,6,14-triol, 17-(cyclobutylmethyl)-4,5-epoxy-, (5alpha,6alpha)-',
#  'CID000004666': '[4,12-Diacetyloxy-15-(3-benzamido-2-hydroxy-3-phenylpropanoyl)oxy-1,9-dihydroxy-10,14,17,17-tetramethyl-11-oxo-6-oxatetracyclo[11.3.1.03,10.04,7]heptadec-13-en-2-yl] benzoate',
#  'CID000003642': '[11-Hydroxy-17-(2-hydroxyacetyl)-10,13-dimethyl-3-oxo-2,6,7,8,9,11,12,14,15,16-decahydro-1H-cyclopenta[a]phenanthren-17-yl] butanoate',
#  'CID000001046': 'Pyrazinamide',
#  'CID000054374': '10-(4-Aminobutyl)-19-[(2-amino-3-phenylpropanoyl)amino]-16-benzyl-N-[(2R,3R)-1,3-dihydroxybutan-2-yl]-7-(1-hydroxyethyl)-13-(1H-indol-3-ylmethyl)-6,9,12,15,18-pentaoxo-1,2-dithia-5,8,11,14,17-pentazacycloicosane-4-carboxamide',
#  'CID000001983': 'Acetaminophen',
#  'CID000002676': '7-[4-(4-Fluorophenyl)-5-(methoxymethyl)-2,6-di(propan-2-yl)pyridin-3-yl]-3,5-dihydroxyhept-6-enoic acid',
#  'CID000003198': 'Econazole',
#  'CID000003928': 'Lincomycine',
#  'CID000068740': 'Zoledronic acid',
#  'CID000005651': '4-Methyl-2-(methylamino)pentanoyl]amino}-20,23,26,42,44',
#  'CID000002142': 'Briclin',
#  'CID000004603': 'Ethyl 4-acetamido-5-amino-3-pentan-3-yloxycyclohexene-1-carboxylate',
#  'CID000130881': 'Olmesartan medoxomil',
#  'CID000003121': 'Valproic acid',
#  'CID000004428': '17-(Cyclopropylmethyl)-4,5alpha-epoxy-3,14-dihydroxymorphinan-6-one',
#  'CID000060852': 'Ibandronic Acid',
#  'CID000002949': 'Pregna-2,4-dien-20-yno[2,3-d]isoxazol-17-ol, (17alpha)-',
#  'CID000001978': 'Acebutolol',
#  'CID000000158': '8-Iso PROSTAGLANDIN E2',
#  'CID000003869': 'Labetalol',
#  'CID000034312': 'Oxcarbazepine',
#  'CID000000564': 'Aminocaproic acid',
#  'CID000156419': 'Cinacalcet',
#  'CID000027686': '5-[3-(2-Carboxy-4-oxochromen-6-yl)oxy-2-hydroxypropoxy]-4-oxochromene-2-carboxylic acid',
#  'CID000002713': 'Chlorhexidine Base',
#  'CID000000085': 'Carnitinium',
#  'CID000077993': 'Eletriptan',
#  'CID000003702': 'Indapamide',
#  'CID000005184': '(-)-Scopolamine',
#  'CID000005466': '1-[4,4-Bis(3-methylthiophen-2-yl)but-3-en-1-yl]piperidine-3-carboxylic acid',
#  'CID000004178': 'Mexiletine',
#  'CID000002375': 'Bicalutamide',
#  'CID000003117': 'Disulfiram',
#  'CID000005596': 'Regurin',
#  'CID000003763': 'Isoflurane',
#  'CID000060835': 'Duloxetine',
#  'CID000002646': '7-[[2-Amino-2-(4-hydroxyphenyl)-1-oxoethyl]amino]-8-oxo-3-prop-1-enyl-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylic acid',
#  'CID000004499': 'Nisoldipine',
#  'CID000002512': 'N-[3-(Dimethylamino)propyl]-N-(ethylcarbamoyl)-7-prop-2-enyl-6,6a,8,9,10,10a-hexahydro-4H-indolo[4,3-fg]quinoline-9-carboxamide',
#  'CID000003114': 'Disopyramide',
#  'CID000005650': "N-Pentanoyl-N-{[2'-(1H-tetrazol-5-yl)biphenyl-4-yl]methyl}-L-valine",
#  'CID000003414': 'Phosphonatoformate',
#  'CID000002099': 'Alosetron',
#  'CID000003454': 'CID 3454',
#  'CID000003675': 'Phenelzine',
#  'CID000004058': 'Meperidine',
#  'CID000004539': 'Norfloxacin',
#  'CID000110635': 'Tadalafil',
#  'CID000004075': 'Mesalamine',
#  'CID000004991': 'Pyridostigmine',
#  'CID000004044': 'Mefenamic acid',
#  'CID000002995': 'Desipramine',
#  'CID000060184': "2'-Epi-Perindopril, (2'R)-",
#  'CID000004674': 'Pamidronic acid',
#  'CID000004205': 'Mirtazapine',
#  'CID000005095': 'Ropinirole',
#  'CID000104865': 'Bosentan',
#  'CID000002141': 'Amifostine',
#  'CID000004771': 'Phentermine',
#  'CID000060877': 'Emtricitabine',
#  'CID000002130': 'Amantadine',
#  'CID000152945': '(1S,3As,3bS,5aR,9aR,11aS)-N-[2,5-bis(trifluoromethyl)phenyl]-9a,11a-dimethyl-7-oxo-1,2,3,3a,3b,4,5,5a,6,9b,10,11-dodecahydroindeno[5,4-f]quinoline-1-carboxamide',
#  'CID000071329': 'Dofetilide',
#  'CID000060843': 'CID 60843',
#  'CID000002519': 'Caffeine',
#  'CID000005029': 'Rabeprazole',
#  'CID000005408': 'Virormone',
#  'CID000005978': 'Vincristine',
#  'CID000150311': 'Ezetimibe',
#  'CID000003040': '6-({[3-(2,6-Dichlorophenyl)-5-methyl-1,2-oxazol-4-yl]carbonyl}amino)-3,3-dimethyl-7-oxo-4-thia-1-azabicyclo[3.2.0]heptane-2-carboxylate',
#  'CID000064147': 'CID 64147',
#  'CID000005381': 'Tazarotene',
#  'CID000004064': 'Meprobamate',
#  'CID000002712': 'Chlordiazepoxide',
#  'CID000024486': 'Calcium chloride, hexahydrate',
#  'CID000060164': 'Adapalene',
#  'CID000002478': 'Busulfan',
#  'CID000003278': 'Ethacrynic acid',
#  'CID000003373': 'Flumazenil',
#  'CID000002622': '7-[[2-(2-Amino-1,3-thiazol-4-yl)-2-methoxyiminoacetyl]amino]-3-[(1-methylpyrrolidin-1-ium-1-yl)methyl]-8-oxo-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylate',
#  'CID000004856': 'CID 4856',
#  'CID000032797': '(9R,17R)-17-(2-Chloroacetyl)-9-fluoro-11,17-dihydroxy-10,13,16-trimethyl-6,7,8,11,12,14,15,16-octahydrocyclopenta[a]phenanthren-3-one',
#  'CID000002610': 'Oracefal',
#  'CID000004819': '2(3H)-Furanone, 3-ethyldihydro-4-[(1-methyl-1H-imidazol-5-yl)methyl]-, (3S-cis)-',
#  'CID000005453': 'Thiotepa',
#  'CID000003914': 'Bunolol',
#  'CID000003784': 'Isradipine',
#  'CID000014888': 'Arsenic trioxide',
#  'CID000002708': 'Chlorambucil',
#  'CID000170361': 'Varenicline',
#  'CID000005734': 'Zonisamide',
#  'CID000004911': 'Probenecid',
#  'CID000004449': 'Nefazodone',
#  'CID000003066': 'Dihydroegotamine',
#  'CID000087177': '4-O-alpha-D-Glucopyranosyl-D-fructose',
#  'CID000000119': 'gamma-Aminobutyric acid',
#  'CID000054688': 'Biaxin XL',
#  'CID000005376': '2-[4-(1,2-Diphenylbut-1-enyl)phenoxy]-N,N-dimethylethanamine',
#  'CID000004053': 'Sarcolysin',
#  'CID000003964': 'Loxapine',
#  'CID000004425': 'Morphinan-6-one, 4,5-epoxy-3,14-dihydroxy-17-(2-propenyl)-, (5alpha)-',
#  'CID000002274': '2-[[1-(2-Amino-1,3-thiazol-4-yl)-2-[(2-methyl-4-oxo-1-sulfoazetidin-3-yl)amino]-2-oxoethylidene]amino]oxy-2-methylpropanoic acid',
#  'CID000004616': 'Oxazepam',
#  'CID000005525': '1-[2-[(1-Ethoxy-1-oxo-4-phenylbutan-2-yl)amino]propanoyl]-2,3,3a,4,5,6,7,7a-octahydroindole-2-carboxylic acid',
#  'CID000005155': 'Stavudine (d4T)',
#  'CID000004675': '[17-Acetyloxy-10,13-dimethyl-2,16-bis(1-methylpiperidin-1-ium-1-yl)-2,3,4,5,6,7,8,9,11,12,14,15,16,17-tetradecahydro-1H-cyclopenta[a]phenanthren-3-yl] acetate',
#  'CID000010631': 'Medroxyprogesterone',
#  'CID000004845': 'Pirbuterol',
#  'CID000003734': 'Bracco 15000',
#  'CID000002973': 'Deferoxamine',
#  'CID000003461': '4-Amino-1-[3,3-difluoro-4-hydroxy-5-(hydroxymethyl)-2-oxolanyl]-2-pyrimidinone',
#  'CID000005297': "D-Streptamine, O-2-deoxy-2-(methylamino)-alpha-L-glucopyranosyl-(1.fwdarw.2)-O-5-deoxy-3-C-formyl-alpha-L-lyxofuranosyl-(1.fwdarw.4)-N,N'-bis(aminoiminomethyl)-",
#  'CID000123620': 'B.Mometason',
#  'CID000054808': 'Chloromethyl (8xi,9xi,11beta,14xi,17alpha)-17-[(ethoxycarbonyl)oxy]-11-hydroxy-3-oxoandrosta-1,4-diene-17-carboxylate',
#  'CID000013342': 'Vinblastine',
#  'CID000002732': 'Chlorthalidone',
#  'CID000003827': 'Ketotifen',
#  'CID000148192': 'Atazanavir',
#  'CID000003372': 'Fluphenazine',
#  'CID000048175': '[(6S,9R,16S,17R)-17-(2-Chloroacetyl)-6,9-difluoro-11-hydroxy-10,13,16-trimethyl-3-oxo-6,7,8,11,12,14,15,16-octahydrocyclopenta[a]phenanthren-17-yl] propanoate',
#  'CID000004748': 'Perphenazine',
#  'CID000002637': '3-[(Carbamoyloxy)methyl]-7-methoxy-8-oxo-7-[(thiophen-2-ylacetyl)amino]-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylate',
#  'CID000054841': 'Atomoxetine',
#  'CID000060953': 'Capecitabine',
#  'CID000047320': 'Atracurium besylate',
#  'CID000003394': 'Flurbiprofen',
#  'CID000002177': '[(3S)-Oxolan-3-yl] N-[(2S,3R)-4-[(4-aminophenyl)sulfonyl-(2-methylpropyl)amino]-3-hydroxy-1-phenylbutan-2-yl]carbamate',
#  'CID000005035': 'Raloxifene',
#  'CID000003467': 'Gentamicin',
#  'CID000002019': 'Actinomycin D',
#  'CID000005472': 'Ticlopidine',
#  'CID000002733': 'Chlorzoxazone',
#  'CID000004730': '3,3-Dimethyl-7-oxo-6-[(2-phenoxyacetyl)amino]-4-thia-1-azabicyclo[3.2.0]heptane-2-carboxylate',
#  'CID000056959': 'Ranolazine',
#  'CID000004828': 'Pindolol',
#  'CID000005195': 'Deprenyl',
#  'CID000003821': 'Ketamine',
#  'CID000036339': 'Amidate',
#  'CID004659568': '2-Cyano-3-(3,4-dihydroxy-5-nitrophenyl)-N,N-diethylprop-2-enamide',
#  'CID005282226': 'Travoprost',
#  'CID000005394': 'Temozolomide',
#  'CID000005719': 'Zaleplon',
#  'CID000003494': 'Glycopyrronium bromide',
#  'CID000004607': '3,3-Dimethyl-6-{[(5-methyl-3-phenylisoxazol-4-yl)carbonyl]amino}-7-oxo-4-thia-1-azabicyclo[3.2.0]heptane-2-carboxylate',
#  'CID000160051': 'Colesevelam',
#  'CID000074989': 'Atovaquone',
#  'CID000148211': 'Palonosetron, (3aR)-',
#  'CID000005578': 'Trimethoprim',
#  'CID000071616': 'Voriconazole',
#  'CID000005572': 'Trihexyphenidyl',
#  'CID000027991': 'Ddavp',
#  'CID000003059': 'Diflunisal',
#  'CID000005215': 'Sulfadiazine',
#  'CID000077999': 'Rosiglitazone',
#  'CID000124087': 'Desloratadine',
#  'CID000002283': 'Chembl3039230',
#  'CID000122316': 'N-2-Propynyl-1-indanamine',
#  'CID003468412': '20-(4-Amino-3,5-dihydroxy-6-methyloxan-2-yl)oxy-4,6,8,11,12,16,18,36-octahydroxy-35,37,38-trimethyl-2,14-dioxo-1-oxacyclooctatriaconta-21,23,25,27,31,33-hexaene-17-carboxylic acid',
#  'CID000004473': 'Benzyl-[2-[5-methoxycarbonyl-2,6-dimethyl-4-(3-nitrophenyl)-1,4-dihydropyridine-3-carbonyl]oxyethyl]-methylazanium',
#  'CID000047725': 'Goserelinacetate',
#  'CID000028112': 'Lithium tetrahydridoaluminate',
#  'CID000004440': 'Naratriptan',
#  'CID000003741': 'Ioversol',
#  'CID000004095': 'Methadone',
#  'CID000004497': 'Nimodipine',
#  'CID000125017': 'Desvenlafaxine',
#  'CID000004451': 'N-Tert-butyl-2-[2-hydroxy-3-[(3-hydroxy-2-methylbenzoyl)amino]-4-phenylsulfanylbutyl]-3,4,4a,5,6,7,8,8a-octahydro-1H-isoquinoline-3-carboxamide',
#  'CID000024011': 'Selenium sulfide',
#  'CID000004542': 'Ovrette',
#  'CID000003382': 'Lidex',
#  'CID000019090': 'Megestrol',
#  'CID004475485': '7-[4-(4-Fluorophenyl)-2-[methyl(methylsulfonyl)amino]-6-propan-2-ylpyrimidin-5-yl]-3,5-dihydroxyheptanoic acid',
#  'CID000060854': 'Ziprasidone',
#  'CID000667490': 'Mercaptopurine',
#  'CID000012536': '(2S,4R,8S,12S)-11-Hydroxy-8-(2-hydroxyacetyl)-6,6,9,13-tetramethyl-5,7-dioxapentacyclo[10.8.0.02,9.04,8.013,18]icosa-14,17-dien-16-one',
#  'CID000060754': 'Gadodiamide',
#  'CID000005584': 'Trimipramine',
#  'CID000119182': 'Clofarabine',
#  'CID003081884': 'Glatiramer acetate',
#  'CID000004195': 'Midodrine',
#  'CID000002800': 'Clomifene',
#  'CID000000298': '2,2-Dichloro-N-[1,3-dihydroxy-1-(4-nitrophenyl)propan-2-yl]acetamide',
#  'CID000197712': '(+/-)-Ambrisentan',
#  'CID000004506': 'Nitrazepam',
#  'CID000003724': 'Iodixanol',
#  'CID000072467': '3-[[2-[2-[2-[[2-[[4-[[2-[[6-Amino-2-[3-amino-1-[(2,3-diamino-3-oxopropyl)amino]-3-oxopropyl]-5-methylpyrimidine-4-carbonyl]amino]-3-[(2R,3S,4S,5S,6S)-3-[(2R,3S,4S,5R,6R)-4-carbamoyloxy-3,5-dihydroxy-6-(hydroxymethyl)oxan-2-yl]oxy-4,5-dihydroxy-6-(hydroxymethyl)oxan-2-yl]oxy-3-(1H-imidazol-5-yl)propanoyl]amino]-3-hydroxy-2-methylpentanoyl]amino]-3-hydroxybutanoyl]amino]ethyl]-1,3-thiazol-4-yl]-1,3-thiazole-4-carbonyl]amino]propyl-dimethylsulfanium',
#  'CID000119607': 'Valdecoxib',
#  'CID000041317': '9-(4-Methoxy-2,3,6-trimethylphenyl)-3,7-dimethyl-2,4,6,8-nonatetraenoic acid',
#  'CID000009052': 'CID 9052',
#  'CID000004745': '8beta-[(Methylthio)methyl]-6-propylergoline',
#  'CID000004834': '6-{[{[(4-Ethyl-2,3-dioxopiperazin-1-yl)carbonyl]amino}(phenyl)acetyl]amino}-3,3-dimethyl-7-oxo-4-thia-1-azabicyclo[3.2.0]heptane-2-carboxylate',
#  'CID000002369': 'Betaxolol',
#  'CID000060696': '[(2S,3S,10S,13S,16S,17R)-3-Hydroxy-10,13-dimethyl-2-morpholin-4-yl-16-(1-prop-2-enylpyrrolidin-1-ium-1-yl)-2,3,4,5,6,7,8,9,11,12,14,15,16,17-tetradecahydro-1H-cyclopenta[a]phenanthren-17-yl] acetate',
#  'CID003002190': 'Telithromycin',
#  'CID000005210': 'Sibutramine',
#  'CID000005878': 'Oxandrolone',
#  'CID000005352': '2-[6-Fluoro-2-methyl-3-[(4-methylsulfinylphenyl)methylidene]-1-indenyl]acetic acid',
#  'CID000009433': 'Aminophylline',
#  'CID000002215': '6-Methyl-5,6,6a,7-tetrahydro-4H-dibenzo[de,g]quinoline-10,11-diol',
#  'CID000003291': 'Ethosuximide',
#  'CID000060815': 'Remifentanil',
#  'CID000004932': 'Propafenone',
#  'CID000002675': 'Cefixime Impurity D',
#  'CID000004993': 'Pyrimethamine',
#  'CID000005771': 'Oxytocin acetate salt hydrate',
#  'CID000153941': 'CID 153941',
#  'CID000003397': 'Flutamide',
#  'CID005311297': '2-[2-[(3R)-3-[3-[(E)-2-(7-Chloroquinolin-2-yl)ethenyl]phenyl]-3-sulfanylpropyl]phenyl]propan-2-ol',
#  'CID000093860': '[(1S)-3-Methyl-1-[[(2R)-3-phenyl-2-(pyrazine-2-carbonylamino)propanoyl]amino]butyl]boronic acid',
#  'CID000057537': '1-Naphthalenol, 5,6,7,8-tetrahydro-6-[propyl[2-(2-thienyl)ethyl]amino]-',
#  'CID000001134': 'L-Thymidine',
#  'CID000005746': 'Mitomycin',
#  'CID000004727': 'DL-Penicillamine',
#  'CID000060612': 'Levomedetomidine',
#  'CID000042113': 'Desflurane',
#  'CID005282044': 'CID 5282044',
#  'CID000041774': 'Precose',
#  'CID000071158': 'Acamprosate',
#  'CID000056339': 'Fosphenytoin',
#  'CID000004739': 'CO-Vidarabine',
#  'CID000002727': 'Chlorpropamide',
#  'CID000060198': 'Exemestane',
#  'CID000002725': 'Chlorpheniramine',
#  'CID000004893': 'Prazosin',
#  'CID000002673': '7-[2-(1,4-Cyclohexadien-1-yl)-2-aminoacetylamino]-3-methyl-8-oxo-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylic acid',
#  'CID000060787': '(2S)-N-[(2S,3R)-4-[(3S)-3-(Tert-butylcarbamoyl)-3,4,4a,5,6,7,8,8a-octahydro-1H-isoquinolin-2-yl]-3-hydroxy-1-phenylbutan-2-yl]-2-(quinoline-2-carbonylamino)butanediamide',
#  'CID000005486': 'R-Tirofiban',
#  'CID000039860': '9H-Dibenzo(b,d)pyran-9-one, 3-(1,1-dimethylheptyl)-6,6a,7,8,10,10a-hexahydro-1-hydroxy-6,6-dimethyl-',
#  'CID000072938': '7-[3-(Aminomethyl)-4-methoxyimino-1-pyrrolidinyl]-1-cyclopropyl-6-fluoro-4-oxo-1,8-naphthyridine-3-carboxylic acid',
#  'CID000005454': 'Thiothixene',
#  'CID000002719': 'Chloroquine',
#  'CID000443871': '(2R)-3-Phenyl-2-[[(1S,3S)-3-propan-2-ylcyclohexanecarbonyl]amino]propanoic acid',
#  'CID000005593': 'Tropicamide',
#  'CID000004140': 'N-(1-Hydroxybutan-2-yl)-7-methyl-6,6a,8,9-tetrahydro-4H-indolo[4,3-fg]quinoline-9-carboxamide',
#  'CID000065027': 'CID 65027',
#  'CID000003730': 'Iohexol',
#  'CID000123631': 'Gefitinib',
#  'CID000036811': 'Dobutamine',
#  'CID000054786': '2-[[(1S,2S,3Ar,9aR)-2-hydroxy-1-[(3R)-3-hydroxyoctyl]-2,3,3a,4,9,9a-hexahydro-1H-cyclopenta[g]naphthalen-5-yl]oxy]acetic acid',
#  'CID000091270': 'Moexipril',
#  'CID000444013': 'Gadoversetamide',
#  'CID000123606': 'Almotriptan',
#  'CID000110634': 'CID 110634',
#  'CID000150310': "Methyl (1R,2S,9R,11S,14R,15S)-2,15-dimethyl-5,5'-dioxospiro[18-oxapentacyclo[8.8.0.01,17.02,7.011,15]octadec-6-ene-14,2'-oxolane]-9-carboxylate",
#  'CID000005515': "10-[(Dimethylamino)methyl]-4-ethyl-4,9-dihydroxy-1H-pyrano[3',4':6,7]indolizino[1,2-b]quinoline-3,14(4H,12H)-dione",
#  'CID000005530': 'Tranylcypromine',
#  'CID000051263': 'Alfentanil',
#  'CID004183806': 'Methyl 7-[3-hydroxy-2-(4-hydroxy-4-methyloct-1-enyl)-5-oxocyclopentyl]heptanoate',
#  'CID000504578': '(2S,3S,4R,5R,6R)-5-Amino-6-[(2R,3S,4R,5S)-5-[(1R,2S,3R,6R)-3-amino-6-[(1S,2R,3R,4R,5R)-2-amino-5-(aminomethyl)-3,4-dihydroxycyclohexyl]oxy-2-hydroxycyclohexyl]oxy-4-hydroxy-2-(hydroxymethyl)oxolan-3-yl]oxy-2-(aminomethyl)oxane-3,4-diol',
#  'CID005311039': 'N-[(3S,6S,9S,11R,15S,18S,20R,21S,24S)-21-(2-Aminoethylamino)-3-[(1R)-3-amino-1-hydroxypropyl]-6-[(1S,2S)-1,2-dihydroxy-2-(4-hydroxyphenyl)ethyl]-11,20-dihydroxy-15-[(1R)-1-hydroxyethyl]-2,5,8,14,17,23-hexaoxo-1,4,7,13,16,22-hexazatricyclo[22.3.0.09,13]heptacosan-18-yl]-10,12-dimethyltetradecanamide',
#  'CID000071273': 'N-(2,6-Dimethylphenyl)-1-propylpiperidine-2-carboxamide',
#  'CID000213039': 'Darunavir',
#  'CID000216326': 'Lenalidomide',
#  'CID000216239': 'Sorafenib',
#  'CID000002170': 'Amoxapine',
#  'CID000060871': 'Adefovir dipivoxil',
#  'CID000002370': 'Bethanechol',
#  'CID000115237': 'Paliperidone',
#  'CID000131536': 'Fosamprenavir',
#  'CID000054547': '7-[[2-(2-Amino-1,3-thiazol-4-yl)-2-methoxyiminoacetyl]amino]-3-(methoxymethyl)-8-oxo-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylic acid',
#  'CID000057469': 'Imiquimod',
#  'CID000444033': '2-[(1S,2S,4R,8S,9S,11S,12S,13R)-6-Cyclohexyl-11-hydroxy-9,13-dimethyl-16-oxo-5,7-dioxapentacyclo[10.8.0.0^{2,9}.0^{4,8}.0^{13,18}]icosa-14,17-dien-8-yl]-2-oxoethyl 2-methylpropanoate',
#  'CID000657298': 'Propylthiouracil',
#  'CID000005721': '4-Guanidino-5-(acetylamino)-6-(1,2,3-trihydroxypropyl)-5,6-dihydro-4H-pyran-2-carboxylic acid',
#  'CID000176168': 'Fosrenol',
#  'CID005311048': 'Dichloromethanediamine',
#  'CID000176870': 'Erlotinib',
#  'CID000004645': 'CID 4645',
#  'CID000003637': 'Hydralazine',
#  'CID000005070': 'Riluzole',
#  'CID000151165': 'CID 151165',
#  'CID000104741': 'Fulvestrant',
#  'CID000002349': 'Pentids',
#  'CID000150610': 'Ertapenem',
#  'CID003062316': 'Dasatinib',
#  'CID000147912': '4-[4-[4-[4-[[(5R)-5-(2,4-Difluorophenyl)-5-(1,2,4-triazol-1-ylmethyl)oxolan-3-yl]methoxy]phenyl]piperazin-1-yl]phenyl]-2-[(2S,3S)-2-hydroxypentan-3-yl]-1,2,4-triazol-3-one',
#  'CID005311181': 'Iloprost',
#  'CID000004913': 'Procainamide',
#  'CID000077992': 'Frovatriptan',
#  'CID000508230': '2-(4-Hydroxy-6-methoxy-7-methyl-3-oxo-1H-isobenzofuran-5-yl)acetic acid',
#  'CID005281007': 'CID 5281007',
#  'CID000002551': 'Carbastat',
#  'CID001349907': 'Methimazole',
#  'CID005311027': 'Bimatoprost',
#  'CID000004011': 'Maprotiline',
#  'CID000002232': '1-[2-[(3-Methyl-1,2,3,4-tetrahydroquinoline-8-yl)sulfonylamino]-5-guanidinopentanoyl]-4-methylpiperidine-2-carboxylic acid',
#  'CID000005052': 'Yohimban-16-carboxylic acid, 11,17-dimethoxy-18-[(3,4,5-trimethoxybenzoyl)oxy]-, methyl ester, (3beta,16beta,17alpha,18beta,20alpha)-',
#  'CID000163742': '(2S,3S,4R,5R,6R)-6-[(2R,3R,4R,5R)-6-[(2R,3S,4S,5R,6R)-2-Carboxy-4-hydroxy-6-[(2R,3S,4R,5R,6S)-4-hydroxy-6-methoxy-5-(sulfoamino)-2-(sulfooxymethyl)oxan-3-yl]oxy-5-sulfooxyoxan-3-yl]oxy-5-(sulfoamino)-4-sulfooxy-2-(sulfooxymethyl)oxan-3-yl]oxy-3-[(2R,3R,4R,5S,6R)-4,5-dihydroxy-3-(sulfoamino)-6-(sulfooxymethyl)oxan-2-yl]oxy-4,5-dihydroxyoxane-2-carboxylic acid',
#  'CID000002182': 'CID 2182',
#  'CID000051634': 'Miglustat',
#  'CID000145068': 'Nitric oxide',
#  'CID005329102': 'Sunitinib',
#  'CID005381226': 'CID 5381226',
#  'CID006398525': 'CID 6398525',
#  'CID005493444': 'Aliskiren',
#  'CID005353980': 'CID 5353980',
#  'CID005481350': 'Tenofovir disoproxil',
#  'CID006447131': '(1R,9S,12S,13R,14S,17R,18Z,21S,23S,24R,25S,27R)-12-[(E)-1-[(1R,3R,4S)-4-Chloro-3-methoxycyclohexyl]prop-1-en-2-yl]-17-ethyl-1,14-dihydroxy-23,25-dimethoxy-13,19,21,27-tetramethyl-11,28-dioxa-4-azatricyclo[22.3.1.04,9]octacos-18-ene-2,3,10,16-tetrone',
#  'CID006398970': '(6R,7R)-7-[[2-(2-Amino-4-thiazolyl)-2-hydroxyimino-1-oxoethyl]amino]-3-ethenyl-8-oxo-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylic acid',
#  'CID005281104': 'Paricalcitol',
#  'CID005487301': 'CID 5487301',
#  'CID005311082': '2-[(1R,4S,10S,13S,19S)-19-[4-(Diaminomethylideneamino)butyl]-10-(1H-indol-3-ylmethyl)-3,9,12,15,18,21,27-heptaoxo-24,25-dithia-2,8,11,14,17,20-hexazatricyclo[18.6.1.04,8]heptacosan-13-yl]acetic acid',
#  'CID006918453': 'Ridauran',
#  'CID005493381': 'CID 5493381',
#  'CID004479097': 'Cobalt;[5-(5,6-dimethylbenzimidazol-1-yl)-4-hydroxy-2-(hydroxymethyl)oxolan-3-yl] 1-[3-[2,13,18-tris(2-amino-2-oxoethyl)-7,12,17-tris(3-amino-3-oxopropyl)-3,5,8,8,13,15,18,19-octamethyl-2,7,12,17-tetrahydro-1H-corrin-21-id-3-yl]propanoylamino]propan-2-yl phosphate;hydrate',
#  'CID005362070': 'CID 5362070',
#  'CID005362420': 'Visudyne',
#  'CID006436173': 'Rifaximin',
#  'CID000003384': 'Fluoromethalone',
#  'CID006435110': 'Ivomec',
#  'CID004659569': 'Tolcapone',
#  'CID000082146': 'Bexarotene',
#  'CID000002266': 'Azelaic acid',
#  'CID005473385': '2-Amino-3,5-dihydropurine-6-thione',
#  'CID000003562': 'Halothane',
#  'CID000012620': 'Docosanol',
#  'CID000040976': '(17R)-13-Ethyl-17-ethynyl-17-hydroxy-11-methylidene-2,6,7,8,9,10,12,14,15,16-decahydro-1H-cyclopenta[a]phenanthren-3-one',
#  'CID000003381': 'Flucort',
#  'CID003086258': 'Polyhematoporphyrin',
#  'CID009571074': 'CID 9571074',
#  'CID000005482': 'Tioconazole'}

# %%
# Import dataset
df_poly_se = pd.read_csv("data/ChChSe-Decagon_polypharmacy.csv")
df_poly_se.columns = ['drug_1_code', 'drug_2_code', 'side_effect_code', 'side_effect_description']

# Perform code-name mapping
df_poly_se['drug_1_name'] = df_poly_se['drug_1_code'].map(cid_mapping)
df_poly_se['drug_2_name'] = df_poly_se['drug_2_code'].map(cid_mapping)

# Rearrange columns
new_cols = ['drug_1_code', 'drug_1_name', 'drug_2_code', 'drug_2_name', 
            'side_effect_code', 'side_effect_description']

df_poly_se = df_poly_se[new_cols]
df_poly_se.head()
# Out:
#     drug_1_code                                        drug_1_name  \
# 0  CID000002173  6-{[Amino(phenyl)acetyl]amino}-3,3-dimethyl-7-...
# 1  CID000002173  6-{[Amino(phenyl)acetyl]amino}-3,3-dimethyl-7-...
# 2  CID000002173  6-{[Amino(phenyl)acetyl]amino}-3,3-dimethyl-7-...
# 3  CID000002173  6-{[Amino(phenyl)acetyl]amino}-3,3-dimethyl-7-...
# 4  CID000002173  6-{[Amino(phenyl)acetyl]amino}-3,3-dimethyl-7-...
#
#     drug_2_code drug_2_name side_effect_code     side_effect_description
# 0  CID000003345    Fentanyl         C0151714             hypermagnesemia
# 1  CID000003345    Fentanyl         C0035344  retinopathy of prematurity
# 2  CID000003345    Fentanyl         C0004144                 atelectasis
# 3  CID000003345    Fentanyl         C0002063                   alkalosis
# 4  CID000003345    Fentanyl         C0004604                   Back Ache

# %%
df_poly_se['side_effect_description'].value_counts()[:20]
# Out:
# arterial pressure NOS decreased    28568
# anaemia                            27006
# Difficulty breathing               26037
# nausea                             25190
# neumonia                           24430
# Fatigue                            24260
# Pain                               23894
# diarrhea                           23848
# asthenia                           23515
# emesis                             23043
# edema extremities                  21981
# body temperature increased         21806
# pleural pain                       21781
# abdominal pain                     21410
# Hypoventilation                    21322
# chest pain                         21013
# dizziness                          20204
# Back Ache                          19930
# Head ache                          19803
# High blood pressure                19376
# Name: side_effect_description, dtype: int64

# %%
drugs = (df_poly_se['drug_1_name'].value_counts()).append(df_poly_se['drug_2_name'].value_counts())
drugs[:20]
# Out:
# DL-Thyroxine                                                                                           68416
# Salbutamol                                                                                             65709
# Acetaminophen                                                                                          62959
# Citalopram                                                                                             55784
# Celecoxib                                                                                              54811
# Bupropion                                                                                              54510
# Alendronic acid                                                                                        49899
# 2-(6-Methoxy-2-naphthyl)propionic acid                                                                 48028
# Heparin                                                                                                45956
# Diazepam                                                                                               44579
# Clopidogrelum                                                                                          42653
# Cetirizine                                                                                             41945
# Lansoprazole                                                                                           40778
# Alprazolam                                                                                             40770
# Ciprofloxacin                                                                                          40369
# Lorazepam                                                                                              39618
# 7-{[Amino(phenyl)acetyl]amino}-3-methyl-8-oxo-5-thia-1-azabicyclo[4.2.0]oct-2-ene-2-carboxylic acid    38612
# CID 2022                                                                                               38361
# 13-Methyl-6,7,8,9,11,12,14,15,16,17-decahydrocyclopenta[a]phenanthrene-3,17-diol                       38191
# Cyclobenzaprine                                                                                        38066
# dtype: int64

# %%
n = 20
df_poly_se_sm = df_poly_se[['drug_1_name', 'drug_2_name']]
L = Counter([y for x in df_poly_se_sm.values for y in combinations(x, 2)]).most_common(n)

combi_df = pd.DataFrame(L, columns=['Pair', 'Qty'])
print(combi_df)
# Out:
#                                                  Pair  Qty
# 0                          (Lansoprazole, Omeprazole)  540
# 1                           (Celecoxib, Lansoprazole)  524
# 2                             (Omeprazole, Rofecoxib)  494
# 3                               (Rofecoxib, Zolpidem)  478
# 4                             (Celecoxib, Gabapentin)  476
# 5                               (Cetirizine, delta-E)  468
# 6                              (Lorazepam, Rofecoxib)  466
# 7                                (delta-E, Rofecoxib)  465
# 8                                (Celecoxib, delta-E)  462
# 9                              (Omeprazole, Percodan)  461
# 10                              (Celecoxib, Zolpidem)  457
# 11  (Celecoxib, S-(Fluoromethyl) (6S,9R,10S,11S,13...  451
# 12  (3-(1,3-Benzodioxol-5-yloxymethyl)-4-(4-fluoro...  449
# 13                              (Salbutamol, delta-E)  448
# 14                           (Ciprofloxacin, delta-E)  448
# 15                            (Lansoprazole, delta-E)  447
# 16  (Citalopram, 4-(3,4-Dichlorophenyl)-n-methyl-1...  446
# 17  (Rofecoxib, 4-(3,4-Dichlorophenyl)-n-methyl-1,...  443
# 18                           (Citalopram, Gabapentin)  443
# 19                                (Percodan, delta-E)  439

# %% [markdown]
# ___
# #### 2(c) Monopharmacy side effects

# %%
df_mono_se = pd.read_csv("data/ChSe-Decagon_monopharmacy.csv")
df_mono_se.head()
# Out:
#        # STITCH Individual Side Effect                Side Effect Name
# 0  CID003062316               C1096328     central nervous system mass
# 1  CID003062316               C0162830       Photosensitivity reaction
# 2  CID003062316               C1611725    leukaemic infiltration brain
# 3  CID003062316               C0541767  platelet adhesiveness abnormal
# 4  CID003062316               C0242973         Ventricular dysfunction

# %%
# Import dataset
df_mono_se = pd.read_csv("data/ChSe-Decagon_monopharmacy.csv")
df_mono_se.columns = ['drug_code', 'side_effect_code', 'side_effect_description']

# Perform code-name mapping
df_mono_se['drug_name'] = df_mono_se['drug_code'].map(cid_mapping)

# Rearrange columns
new_cols = ['drug_code', 'drug_name', 'side_effect_code', 'side_effect_description']

df_mono_se = df_mono_se[new_cols]
df_mono_se.head()
# Out:
#       drug_code  drug_name side_effect_code         side_effect_description
# 0  CID003062316  Dasatinib         C1096328     central nervous system mass
# 1  CID003062316  Dasatinib         C0162830       Photosensitivity reaction
# 2  CID003062316  Dasatinib         C1611725    leukaemic infiltration brain
# 3  CID003062316  Dasatinib         C0541767  platelet adhesiveness abnormal
# 4  CID003062316  Dasatinib         C0242973         Ventricular dysfunction

# %%
df_mono_se['drug_name'].value_counts()[:15]
# Out:
# Zoledronic acid                                                                                    1550
# Pamidronic acid                                                                                    1515
# 3,7-Dimethyl-9-(2,6,6-trimethylcyclohex-1-en-1-yl)nona-2,4,6,8-tetraenoic acid                     1229
# Bupropion                                                                                          1186
# 1-[3,4-Dihydroxy-5-(hydroxymethyl)-2-oxolanyl]-1,2,4-triazole-3-carboxamide                        1045
# Rofecoxib                                                                                           979
# 2-[4-(1,2-Diphenylbut-1-enyl)phenoxy]-N,N-dimethylethanamine                                        947
# [(1S)-3-Methyl-1-[[(2R)-3-phenyl-2-(pyrazine-2-carbonylamino)propanoyl]amino]butyl]boronic acid     927
# Letrozole                                                                                           896
# CID 2818                                                                                            871
# Capecitabine                                                                                        868
# 1-[(5-Nitro-2-furanyl)methylideneamino]imidazolidine-2,4-dione                                      787
# Chlorhexidine Base                                                                                  782
# Meperidine                                                                                          747
# 5-Fluorouracil                                                                                      737
# Name: drug_name, dtype: int64

# %%
df_mono_se['side_effect_description'].value_counts()[:15]
# Out:
# general physical health deterioration    301
# hypoaesthesia                            279
# mental status changes                    278
# tooth extraction                         276
# emotional distress                       275
# alanine aminotransferase increased       273
# condition aggravated                     270
# pollakiuria                              267
# staphylococcal infection                 266
# blood creatinine increased               263
# bone disorder                            263
# spinal osteoarthritis                    263
# dysgeusia                                257
# anhedonia                                249
# Gastrointestinal disorder                243
# Name: side_effect_description, dtype: int64
